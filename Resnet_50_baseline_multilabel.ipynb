# %% [markdown]
# <a href="https://colab.research.google.com/github/MittalNeha/retinopathy-kaggle/blob/master/Resnet_50_baseline_multilabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import os
import glob
import h5py
import shutil
import imgaug as aug
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mimg
import imgaug.augmenters as iaa
from os import listdir, makedirs, getcwd, remove
from os.path import isfile, join, abspath, exists, isdir, expanduser
from PIL import Image
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize

from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from keras.models import Sequential, load_model
from keras.layers import (Activation, Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, SeparableConv2D,
                          Dense, BatchNormalization, GlobalAveragePooling2D)
from keras.layers import GlobalMaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.merge import Concatenate
from keras.models import Model
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import Sequence
from keras.utils import to_categorical
from keras.losses import binary_crossentropy, categorical_crossentropy

from keras.applications.resnet50 import ResNet50
# from keras.applications.res

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from mlxtend.plotting import plot_confusion_matrix
from keras import metrics
from sklearn.metrics import confusion_matrix, cohen_kappa_score
from sklearn.utils import class_weight, shuffle
import cv2
from keras import backend as K
import tensorflow as tf

from sklearn.preprocessing import MultiLabelBinarizer

from tqdm import tqdm

color = sns.color_palette()
# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
def get_kaggle_data():
  os.environ['KAGGLE_USERNAME'] = "mittalneha"
  os.environ['KAGGLE_KEY'] = "59ec3f992f5fb4b510bebd8dea889381"
  
  # !kaggle competitions download -c aptos2019-blindness-detection
  # !kaggle datasets download -d keras/resnet50
  
  # !mkdir kaggle-data
  # !mv sample_submission.csv kaggle-data/
  # !mv test.csv kaggle-data/
#   !mv train.csv kaggle-data/
  # !unzip test_images.zip -d kaggle-data/test_images
#   !unzip train_images.zip -d kaggle-data/train_images
  # !cp /content/gdrive/My\ Drive/Colab\ Notebooks/aug_train_images.zip .
  # !cp /content/gdrive/My\ Drive/Colab\ Notebooks/aug_train.csv .
  
  # !unzip aug_train_images.zip
  # !mv aug_train_images kaggle-data/
  # !mv aug_train.csv kaggle-data/
  
  
  # !unzip resnet50.zip -d kaggle-data/resnet50/

# %%
# !kaggle datasets download -d keras/resnet50
# !unzip resnet50.zip -d kaggle-data/resnet50/

# %%
# !cp /content/gdrive/My\ Drive/Colab\ Notebooks/resnet50_aug1.zip .
# !unzip resnet50_aug1.zip

# %%
# !mkdir kaggle-data/resnet50
# !mv Resnet50_bestqwk.h5 kaggle-data/resnet50

# %%
data_dir = "kaggle-data"
get_kaggle_data()
# Out:
# Downloading train_images.zip to /content
# 100% 8.01G/8.01G [01:13<00:00, 67.8MB/s]
# 100% 8.01G/8.01G [01:13<00:00, 117MB/s]
# Downloading test_images.zip to /content
#  99% 1.49G/1.50G [00:12<00:00, 135MB/s]
# 100% 1.50G/1.50G [00:12<00:00, 130MB/s]
# Downloading train.csv to /content
#   0% 0.00/53.7k [00:00<?, ?B/s]
# 100% 53.7k/53.7k [00:00<00:00, 56.5MB/s]
# Downloading test.csv to /content
#   0% 0.00/24.5k [00:00<?, ?B/s]
# 100% 24.5k/24.5k [00:00<00:00, 24.0MB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/28.3k [00:00<?, ?B/s]
# 100% 28.3k/28.3k [00:00<00:00, 26.8MB/s]
# Downloading resnet50.zip to /content
#  94% 164M/174M [00:01<00:00, 84.4MB/s]
# 100% 174M/174M [00:02<00:00, 90.4MB/s]
# Archive:  test_images.zip
#   inflating: kaggle-data/test_images/270a532df702.png
#   inflating: kaggle-data/test_images/86fd5df366b2.png
#   inflating: kaggle-data/test_images/72dd7ca97f55.png
#   inflating: kaggle-data/test_images/ec8f3ec97245.png
#   inflating: kaggle-data/test_images/b3db392f5ee8.png
#   inflating: kaggle-data/test_images/c71728f9535b.png
#   inflating: kaggle-data/test_images/c7c003cdaaba.png
#   inflating: kaggle-data/test_images/67b614d32bcc.png
#   inflating: kaggle-data/test_images/e982c6b5b726.png
#   inflating: kaggle-data/test_images/e2fdc91493f4.png
#   inflating: kaggle-data/test_images/1d1539c0fb03.png
#   inflating: kaggle-data/test_images/cefdb6b7fda2.png
#   inflating: kaggle-data/test_images/f898d3e8ed90.png
#   inflating: kaggle-data/test_images/0ccfca342907.png
#   inflating: kaggle-data/test_images/b48785a5f763.png
#   inflating: kaggle-data/test_images/010d915e229a.png
#   inflating: kaggle-data/test_images/2427e06125ae.png
#   inflating: kaggle-data/test_images/8cfa1b047c34.png
#   inflating: kaggle-data/test_images/9295bc2a4c7a.png
#   inflating: kaggle-data/test_images/741ef20e5e28.png
#   inflating: kaggle-data/test_images/cd6cb8eca034.png
#   inflating: kaggle-data/test_images/a78b86e53095.png
#   inflating: kaggle-data/test_images/1f2018b62574.png
#   inflating: kaggle-data/test_images/e7557ee92477.png
#   inflating: kaggle-data/test_images/d29d5d08e8af.png
#   inflating: kaggle-data/test_images/92c773457ab2.png
#   inflating: kaggle-data/test_images/5c1ed0268157.png
#   inflating: kaggle-data/test_images/9c2c32cbda5a.png
#   inflating: kaggle-data/test_images/397ffea483ef.png
#   inflating: kaggle-data/test_images/c7b8aef7c746.png
#   inflating: kaggle-data/test_images/9a7e2e8fa01a.png
#   inflating: kaggle-data/test_images/ac93ddd2c5a7.png
#   inflating: kaggle-data/test_images/cee9079c5c8c.png
#   inflating: kaggle-data/test_images/e051148841ce.png
#   inflating: kaggle-data/test_images/b510ee1cfc21.png
#   inflating: kaggle-data/test_images/09855c888f9f.png
#   inflating: kaggle-data/test_images/f54b2ebf7f43.png
#   inflating: kaggle-data/test_images/f32bdf2a84ec.png
#   inflating: kaggle-data/test_images/c723c0765065.png
#   inflating: kaggle-data/test_images/a00e9f3e46b3.png
#   inflating: kaggle-data/test_images/a1eb5f42737e.png
#   inflating: kaggle-data/test_images/e752f13c725c.png
#   inflating: kaggle-data/test_images/263dde841c5e.png
#   inflating: kaggle-data/test_images/c434df57e02b.png
#   inflating: kaggle-data/test_images/b9f4fa36c061.png
#   inflating: kaggle-data/test_images/ad4c27a10804.png
#   inflating: kaggle-data/test_images/c3fea3498883.png
#   inflating: kaggle-data/test_images/fe57ff56618e.png
#   inflating: kaggle-data/test_images/427110b0a05e.png
#   inflating: kaggle-data/test_images/70115c0f75cf.png
#   inflating: kaggle-data/test_images/cf62a20429e5.png
#   inflating: kaggle-data/test_images/4824f6db2b82.png
#   inflating: kaggle-data/test_images/515877da2def.png
#   inflating: kaggle-data/test_images/e99e5a0b8755.png
#   inflating: kaggle-data/test_images/04a0773c71fb.png
#   inflating: kaggle-data/test_images/065cb18bb0b2.png
#   inflating: kaggle-data/test_images/9600b8ad9d49.png
#   inflating: kaggle-data/test_images/da58ea1e0407.png
#   inflating: kaggle-data/test_images/b90a9ac76003.png
#   inflating: kaggle-data/test_images/64a4926e85b5.png
#   inflating: kaggle-data/test_images/e03bb55dd03c.png
#   inflating: kaggle-data/test_images/fa8b04533b99.png
#   inflating: kaggle-data/test_images/7a5b1c716560.png
#   inflating: kaggle-data/test_images/b01de692186b.png
#   inflating: kaggle-data/test_images/51bbd82feec8.png
#   inflating: kaggle-data/test_images/291069435ace.png
#   inflating: kaggle-data/test_images/96c21d31212c.png
#   inflating: kaggle-data/test_images/74350fe494ba.png
#   inflating: kaggle-data/test_images/74b5ba54d7cc.png
#   inflating: kaggle-data/test_images/2bd279f7c431.png
#   inflating: kaggle-data/test_images/460bc010f96a.png
#   inflating: kaggle-data/test_images/76c854fde95e.png
#   inflating: kaggle-data/test_images/bfeaf538c6ca.png
#   inflating: kaggle-data/test_images/98e2a0c2238d.png
#   inflating: kaggle-data/test_images/881ab102a44e.png
#   inflating: kaggle-data/test_images/15586b5a4a6a.png
#   inflating: kaggle-data/test_images/3e2ae41e0730.png
#   inflating: kaggle-data/test_images/ef36cbd84301.png
#   inflating: kaggle-data/test_images/256dbdb1821c.png
#   inflating: kaggle-data/test_images/0df488d86631.png
#   inflating: kaggle-data/test_images/55ab23df5fa0.png
#   inflating: kaggle-data/test_images/c2fa7e44f4bd.png
#   inflating: kaggle-data/test_images/23766fab438c.png
#   inflating: kaggle-data/test_images/2ace14876108.png
#   inflating: kaggle-data/test_images/f3a6c7df5fdc.png
#   inflating: kaggle-data/test_images/20456efc42ad.png
#   inflating: kaggle-data/test_images/3f03980754e7.png
#   inflating: kaggle-data/test_images/326f05b4fef0.png
#   inflating: kaggle-data/test_images/fc3935afc788.png
#   inflating: kaggle-data/test_images/9efba19d237c.png
#   inflating: kaggle-data/test_images/1784c33b4f27.png
#   inflating: kaggle-data/test_images/c43d6133ca37.png
#   inflating: kaggle-data/test_images/e7655ce118ad.png
#   inflating: kaggle-data/test_images/ab49679c489a.png
#   inflating: kaggle-data/test_images/13a444b80681.png
#   inflating: kaggle-data/test_images/c61d374afa32.png
#   inflating: kaggle-data/test_images/85f608bcb50a.png
#   inflating: kaggle-data/test_images/3a2b37343edd.png
#   inflating: kaggle-data/test_images/8571e10b7294.png
#   inflating: kaggle-data/test_images/6aecc3aa2de7.png
#   inflating: kaggle-data/test_images/5d26d29704ad.png
#   inflating: kaggle-data/test_images/d7251d24ad17.png
#   inflating: kaggle-data/test_images/0928150bb29a.png
#   inflating: kaggle-data/test_images/0af338c60d2d.png
#   inflating: kaggle-data/test_images/dadc953e79e2.png
#   inflating: kaggle-data/test_images/cf00f7ff4409.png
#   inflating: kaggle-data/test_images/66bce216e103.png
#   inflating: kaggle-data/test_images/ba9dbc90fdf1.png
#   inflating: kaggle-data/test_images/fbc8b60526f1.png
#   inflating: kaggle-data/test_images/0cad3584e761.png
#   inflating: kaggle-data/test_images/6ed9e38a4239.png
#   inflating: kaggle-data/test_images/689d5626e98a.png
#   inflating: kaggle-data/test_images/4947431500d5.png
#   inflating: kaggle-data/test_images/a23f0953f08c.png
#   inflating: kaggle-data/test_images/507be4c76d8b.png
#   inflating: kaggle-data/test_images/03be80919be4.png
#   inflating: kaggle-data/test_images/c54f83a2d026.png
#   inflating: kaggle-data/test_images/11dc8d4a66a7.png
#   inflating: kaggle-data/test_images/c3e311d899ed.png
#   inflating: kaggle-data/test_images/443b96e2e048.png
#   inflating: kaggle-data/test_images/ec353d42359d.png
#   inflating: kaggle-data/test_images/ba482933d0e3.png
#   inflating: kaggle-data/test_images/afe3ed0f5671.png
#   inflating: kaggle-data/test_images/18c7998ba166.png
#   inflating: kaggle-data/test_images/3ef3056cc3d0.png
#   inflating: kaggle-data/test_images/3c4329778c68.png
#   inflating: kaggle-data/test_images/a5b28de176ba.png
#   inflating: kaggle-data/test_images/6e48f854f7e6.png
#   inflating: kaggle-data/test_images/6dd2dbd802ea.png
#   inflating: kaggle-data/test_images/995eb7091756.png
#   inflating: kaggle-data/test_images/18d885cd7f0c.png
#   inflating: kaggle-data/test_images/2dec44360855.png
#   inflating: kaggle-data/test_images/f526c7a16749.png
#   inflating: kaggle-data/test_images/9a36c6d23fe8.png
#   inflating: kaggle-data/test_images/5c081b9e1c7f.png
#   inflating: kaggle-data/test_images/bc2a4b1c45b0.png
#   inflating: kaggle-data/test_images/b93f6b61c889.png
#   inflating: kaggle-data/test_images/7f9c86406c62.png
#   inflating: kaggle-data/test_images/264bb74277a5.png
#   inflating: kaggle-data/test_images/7031ca7c5ee1.png
#   inflating: kaggle-data/test_images/a252a97fbaec.png
#   inflating: kaggle-data/test_images/5ad469f293f7.png
#   inflating: kaggle-data/test_images/4a5aad82e737.png
#   inflating: kaggle-data/test_images/b82e6271eaa5.png
#   inflating: kaggle-data/test_images/93b480980afb.png
#   inflating: kaggle-data/test_images/b16787f65d49.png
#   inflating: kaggle-data/test_images/bbc58fd26e9d.png
#   inflating: kaggle-data/test_images/7fe2cff51752.png
#   inflating: kaggle-data/test_images/624ebaffb2ab.png
#   inflating: kaggle-data/test_images/2d64c36a319d.png
#   inflating: kaggle-data/test_images/ae39a208b180.png
#   inflating: kaggle-data/test_images/f9642cf6a5bb.png
#   inflating: kaggle-data/test_images/96a3a01f0522.png
#   inflating: kaggle-data/test_images/dafade8b6561.png
#   inflating: kaggle-data/test_images/d5641bbb70f4.png
#   inflating: kaggle-data/test_images/2f2920b82e56.png
#   inflating: kaggle-data/test_images/30e384252334.png
#   inflating: kaggle-data/test_images/7f3d521363ab.png
#   inflating: kaggle-data/test_images/f6a9c937e6d6.png
#   inflating: kaggle-data/test_images/c56f9d5ae96e.png
#   inflating: kaggle-data/test_images/4db635ee7440.png
#   inflating: kaggle-data/test_images/ef1548136b3f.png
#   inflating: kaggle-data/test_images/e976cf76fe42.png
#   inflating: kaggle-data/test_images/1876ac30fdc5.png
#   inflating: kaggle-data/test_images/3a3b00bad960.png
#   inflating: kaggle-data/test_images/99b6b8ecbcfa.png
#   inflating: kaggle-data/test_images/3d4d693f7983.png
#   inflating: kaggle-data/test_images/6938b334d93b.png
#   inflating: kaggle-data/test_images/ad13303b17c9.png
#   inflating: kaggle-data/test_images/7ca07d02a1ff.png
#   inflating: kaggle-data/test_images/3f007a2060c0.png
#   inflating: kaggle-data/test_images/458b2446e3dd.png
#   inflating: kaggle-data/test_images/48530f602b11.png
#   inflating: kaggle-data/test_images/db682fa7f5b6.png
#   inflating: kaggle-data/test_images/7dcbbc17fe47.png
#   inflating: kaggle-data/test_images/638a49bc4928.png
#   inflating: kaggle-data/test_images/5ebc9dbbe79d.png
#   inflating: kaggle-data/test_images/b8b36543507f.png
#   inflating: kaggle-data/test_images/8939b6701f96.png
#   inflating: kaggle-data/test_images/597ab119ba6d.png
#   inflating: kaggle-data/test_images/f8f530fa573e.png
#   inflating: kaggle-data/test_images/0f23c3028206.png
#   inflating: kaggle-data/test_images/3936578169d1.png
#   inflating: kaggle-data/test_images/f9f3d97f3269.png
#   inflating: kaggle-data/test_images/fcbc1f4b5342.png
#   inflating: kaggle-data/test_images/7c0748d6d669.png
#   inflating: kaggle-data/test_images/25d98da73248.png
#   inflating: kaggle-data/test_images/8d892f6b5976.png
#   inflating: kaggle-data/test_images/f3bf83a0e378.png
#   inflating: kaggle-data/test_images/5db5832b333b.png
#   inflating: kaggle-data/test_images/90f3a3addf92.png
#   inflating: kaggle-data/test_images/32180eca093d.png
#   inflating: kaggle-data/test_images/c49c47887520.png
#   inflating: kaggle-data/test_images/92ebf5417491.png
#   inflating: kaggle-data/test_images/f3f696c65bfd.png
#   inflating: kaggle-data/test_images/80976eb17462.png
#   inflating: kaggle-data/test_images/ce79b62b49f7.png
#   inflating: kaggle-data/test_images/362ee624995d.png
#   inflating: kaggle-data/test_images/fda8612fcc8c.png
#   inflating: kaggle-data/test_images/4e609a790d75.png
#   inflating: kaggle-data/test_images/5d443c9e3d39.png
#   inflating: kaggle-data/test_images/e44c7c93e116.png
#   inflating: kaggle-data/test_images/ea4a8d1b2358.png
#   inflating: kaggle-data/test_images/74342f5181a9.png
#   inflating: kaggle-data/test_images/af894868d352.png
#   inflating: kaggle-data/test_images/6e239ecaad8d.png
#   inflating: kaggle-data/test_images/e229725ddccd.png
#   inflating: kaggle-data/test_images/0edc0c33e929.png
#   inflating: kaggle-data/test_images/41484b672eb5.png
#   inflating: kaggle-data/test_images/1fb4db8834df.png
#   inflating: kaggle-data/test_images/78816c91ac9a.png
#   inflating: kaggle-data/test_images/33b59700691d.png
#   inflating: kaggle-data/test_images/8750b8bfe28a.png
#   inflating: kaggle-data/test_images/8944ffa47333.png
#   inflating: kaggle-data/test_images/49a027e2cebb.png
#   inflating: kaggle-data/test_images/5d2e1e53b383.png
#   inflating: kaggle-data/test_images/25217ad0dfae.png
#   inflating: kaggle-data/test_images/29cb3c00c82e.png
#   inflating: kaggle-data/test_images/496039c25f39.png
#   inflating: kaggle-data/test_images/0a0780ad3395.png
#   inflating: kaggle-data/test_images/8fdecd6a923d.png
#   inflating: kaggle-data/test_images/f5aa838e2ffc.png
#   inflating: kaggle-data/test_images/27c3c04811b6.png
#   inflating: kaggle-data/test_images/76a1bc72e45f.png
#   inflating: kaggle-data/test_images/f543269b7905.png
#   inflating: kaggle-data/test_images/086727c22b75.png
#   inflating: kaggle-data/test_images/659f752cb810.png
#   inflating: kaggle-data/test_images/aa60bff84a4c.png
#   inflating: kaggle-data/test_images/51e88694c81f.png
#   inflating: kaggle-data/test_images/2818509e0fb4.png
#   inflating: kaggle-data/test_images/893b140bd358.png
#   inflating: kaggle-data/test_images/b9ee6ecab720.png
#   inflating: kaggle-data/test_images/f04b0e450206.png
#   inflating: kaggle-data/test_images/d31da0ad1639.png
#   inflating: kaggle-data/test_images/fa09c97a2887.png
#   inflating: kaggle-data/test_images/9240b949fdc0.png
#   inflating: kaggle-data/test_images/f41ef796cc0d.png
#   inflating: kaggle-data/test_images/10df48fe8c6c.png
#   inflating: kaggle-data/test_images/0749255f718d.png
#   inflating: kaggle-data/test_images/7d15cfc7fc45.png
#   inflating: kaggle-data/test_images/e57ddcade9b2.png
#   inflating: kaggle-data/test_images/2884eb727858.png
#   inflating: kaggle-data/test_images/5c3872c226bb.png
#   inflating: kaggle-data/test_images/c5ff8e81f094.png
#   inflating: kaggle-data/test_images/aa381cb2abd2.png
#   inflating: kaggle-data/test_images/69b3f1028e99.png
#   inflating: kaggle-data/test_images/d60e1e5c5c0f.png
#   inflating: kaggle-data/test_images/aad278dd0f28.png
#   inflating: kaggle-data/test_images/9d5061ccc54c.png
#   inflating: kaggle-data/test_images/33a0fb5161e1.png
#   inflating: kaggle-data/test_images/ae43fbdb0db5.png
#   inflating: kaggle-data/test_images/d50c55a3c762.png
#   inflating: kaggle-data/test_images/600b2b469a2f.png
#   inflating: kaggle-data/test_images/848091b1f5d0.png
#   inflating: kaggle-data/test_images/c4a81ee6362b.png
#   inflating: kaggle-data/test_images/d8312c5b5217.png
#   inflating: kaggle-data/test_images/d8f6c660bf2d.png
#   inflating: kaggle-data/test_images/f73e8ec73179.png
#   inflating: kaggle-data/test_images/9ec84fe4292a.png
#   inflating: kaggle-data/test_images/7e1f51fbb458.png
#   inflating: kaggle-data/test_images/898232c36d81.png
#   inflating: kaggle-data/test_images/95dafd1d5f47.png
#   inflating: kaggle-data/test_images/0434995d0654.png
#   inflating: kaggle-data/test_images/b501a5bdd0cc.png
#   inflating: kaggle-data/test_images/a87e705d63ee.png
#   inflating: kaggle-data/test_images/4a51e72940f2.png
#   inflating: kaggle-data/test_images/d465bf00f65f.png
#   inflating: kaggle-data/test_images/657b8609f26f.png
#   inflating: kaggle-data/test_images/cdfa6bafa14b.png
#   inflating: kaggle-data/test_images/2b62b5a21668.png
#   inflating: kaggle-data/test_images/c5f88666d031.png
#   inflating: kaggle-data/test_images/1a495e43fc7d.png
#   inflating: kaggle-data/test_images/0bab4b301d71.png
#   inflating: kaggle-data/test_images/a924c71421de.png
#   inflating: kaggle-data/test_images/ce6af5e7dd4b.png
#   inflating: kaggle-data/test_images/d0ee299b99ca.png
#   inflating: kaggle-data/test_images/447d8e8f446d.png
#   inflating: kaggle-data/test_images/0229c0a80d42.png
#   inflating: kaggle-data/test_images/40d7a111ee7c.png
#   inflating: kaggle-data/test_images/4180f7f0c182.png
#   inflating: kaggle-data/test_images/74c97e963ca4.png
#   inflating: kaggle-data/test_images/89f1314e2c10.png
#   inflating: kaggle-data/test_images/dfcde9f583c0.png
#   inflating: kaggle-data/test_images/7136203550af.png
#   inflating: kaggle-data/test_images/9d3000de91bd.png
#   inflating: kaggle-data/test_images/c1df61ca9c16.png
#   inflating: kaggle-data/test_images/f15d74f144a9.png
#   inflating: kaggle-data/test_images/acb732e347c0.png
#   inflating: kaggle-data/test_images/bda2d5ca6f7c.png
#   inflating: kaggle-data/test_images/d055c5298145.png
#   inflating: kaggle-data/test_images/f4a37bac1050.png
#   inflating: kaggle-data/test_images/779f70ddc126.png
#   inflating: kaggle-data/test_images/06e60df1823e.png
#   inflating: kaggle-data/test_images/9db8a8b68de9.png
#   inflating: kaggle-data/test_images/3d2e3e4113cc.png
#   inflating: kaggle-data/test_images/bc9d8ac89c82.png
#   inflating: kaggle-data/test_images/764b9b51cd9f.png
#   inflating: kaggle-data/test_images/f237bd2d4189.png
#   inflating: kaggle-data/test_images/b75dedf39e2a.png
#   inflating: kaggle-data/test_images/810b9603c241.png
#   inflating: kaggle-data/test_images/a6e5dd321ae4.png
#   inflating: kaggle-data/test_images/fbc502a64901.png
#   inflating: kaggle-data/test_images/2febc332f628.png
#   inflating: kaggle-data/test_images/9f3457c79515.png
#   inflating: kaggle-data/test_images/19fedfb6c8e1.png
#   inflating: kaggle-data/test_images/4a6795dc22f9.png
#   inflating: kaggle-data/test_images/9fe34f463cef.png
#   inflating: kaggle-data/test_images/ccad8575f78c.png
#   inflating: kaggle-data/test_images/8d0bcd4ebff6.png
#   inflating: kaggle-data/test_images/fd2978398705.png
#   inflating: kaggle-data/test_images/c56dff0321fa.png
#   inflating: kaggle-data/test_images/f07ca35b523b.png
#   inflating: kaggle-data/test_images/e44c5eb9cbf3.png
#   inflating: kaggle-data/test_images/91fd830b7677.png
#   inflating: kaggle-data/test_images/9c5ba656e978.png
#   inflating: kaggle-data/test_images/6a54653ad12b.png
#   inflating: kaggle-data/test_images/f47c5fc86387.png
#   inflating: kaggle-data/test_images/3a8bcee20143.png
#   inflating: kaggle-data/test_images/13e28ec4534a.png
#   inflating: kaggle-data/test_images/e4c643b8c321.png
#   inflating: kaggle-data/test_images/a150cde164c1.png
#   inflating: kaggle-data/test_images/3cc1ca3e086b.png
#   inflating: kaggle-data/test_images/0167076e7089.png
#   inflating: kaggle-data/test_images/020921b796d5.png
#   inflating: kaggle-data/test_images/fe84ad1df04b.png
#   inflating: kaggle-data/test_images/2bb39124c823.png
#   inflating: kaggle-data/test_images/e3e124e05aef.png
#   inflating: kaggle-data/test_images/fd4d81b43e84.png
#   inflating: kaggle-data/test_images/c47fe8e08b85.png
#   inflating: kaggle-data/test_images/7b66133d42cf.png
#   inflating: kaggle-data/test_images/e62ae9cc6f9d.png
#   inflating: kaggle-data/test_images/9772f0ba0ee7.png
#   inflating: kaggle-data/test_images/c623cd3dfc93.png
#   inflating: kaggle-data/test_images/b807f431700b.png
#   inflating: kaggle-data/test_images/cbf8916e5abe.png
#   inflating: kaggle-data/test_images/7ba4225b323e.png
#   inflating: kaggle-data/test_images/8f874a9724df.png
#   inflating: kaggle-data/test_images/d2d6fcb41a71.png
#   inflating: kaggle-data/test_images/2e6a99e1df80.png
#   inflating: kaggle-data/test_images/dbcbc3467e56.png
#   inflating: kaggle-data/test_images/ccb7656b082f.png
#   inflating: kaggle-data/test_images/5971c10c1465.png
#   inflating: kaggle-data/test_images/20dd582bf9c7.png
#   inflating: kaggle-data/test_images/49af6f1390b9.png
#   inflating: kaggle-data/test_images/fa7a97f4de76.png
#   inflating: kaggle-data/test_images/beda8915324d.png
#   inflating: kaggle-data/test_images/500586e31827.png
#   inflating: kaggle-data/test_images/4bf29bca6018.png
#   inflating: kaggle-data/test_images/e23d7cd089fa.png
#   inflating: kaggle-data/test_images/70f660f46630.png
#   inflating: kaggle-data/test_images/a252632b8c91.png
#   inflating: kaggle-data/test_images/652a1edabdb7.png
#   inflating: kaggle-data/test_images/a0d3fd0386d9.png
#   inflating: kaggle-data/test_images/1fb1acde9818.png
#   inflating: kaggle-data/test_images/3df3c5e97663.png
#   inflating: kaggle-data/test_images/551f1e4e2763.png
#   inflating: kaggle-data/test_images/7205b4cbc184.png
#   inflating: kaggle-data/test_images/8c41de06d44e.png
#   inflating: kaggle-data/test_images/ff2fd94448de.png
#   inflating: kaggle-data/test_images/ab51d81bb302.png
#   inflating: kaggle-data/test_images/e8deb6e2de83.png
#   inflating: kaggle-data/test_images/fdde61dd1bde.png
#   inflating: kaggle-data/test_images/c66bf1a7d923.png
#   inflating: kaggle-data/test_images/701ac49e32d2.png
#   inflating: kaggle-data/test_images/4686020fa0c6.png
#   inflating: kaggle-data/test_images/ef44b0f4d553.png
#   inflating: kaggle-data/test_images/5092d7fc1392.png
#   inflating: kaggle-data/test_images/1e34e33a0988.png
#   inflating: kaggle-data/test_images/0f8fc606e17c.png
#   inflating: kaggle-data/test_images/a93db82a21e1.png
#   inflating: kaggle-data/test_images/b856313783fb.png
#   inflating: kaggle-data/test_images/6e2d7cee2d91.png
#   inflating: kaggle-data/test_images/dff51d618ebd.png
#   inflating: kaggle-data/test_images/5110fe0bf9cb.png
#   inflating: kaggle-data/test_images/01499815e469.png
#   inflating: kaggle-data/test_images/a5867e3dde29.png
#   inflating: kaggle-data/test_images/75c6563ed058.png
#   inflating: kaggle-data/test_images/00836aaacf06.png
#   inflating: kaggle-data/test_images/e5bab5038b26.png
#   inflating: kaggle-data/test_images/e7a9e0ecdd65.png
#   inflating: kaggle-data/test_images/805103f04fd6.png
#   inflating: kaggle-data/test_images/38496a64a658.png
#   inflating: kaggle-data/test_images/3c142c3f33d7.png
#   inflating: kaggle-data/test_images/4337e1114ad0.png
#   inflating: kaggle-data/test_images/28051dcc7861.png
#   inflating: kaggle-data/test_images/7454c19acf81.png
#   inflating: kaggle-data/test_images/495b3b3cb438.png
#   inflating: kaggle-data/test_images/3da4e0e38f17.png
#   inflating: kaggle-data/test_images/f092448b6617.png
#   inflating: kaggle-data/test_images/e6834d55bf6b.png
#   inflating: kaggle-data/test_images/4db841b2ab70.png
#   inflating: kaggle-data/test_images/a99e7996c664.png
#   inflating: kaggle-data/test_images/d64a07eb634d.png
#   inflating: kaggle-data/test_images/3099f71a8760.png
#   inflating: kaggle-data/test_images/ac601d2e714d.png
#   inflating: kaggle-data/test_images/ec727873cdb7.png
#   inflating: kaggle-data/test_images/24d5ed8ba19a.png
#   inflating: kaggle-data/test_images/4ca3eaf3493f.png
#   inflating: kaggle-data/test_images/6263433f1991.png
#   inflating: kaggle-data/test_images/6ad7b5beef75.png
#   inflating: kaggle-data/test_images/d463abce569a.png
#   inflating: kaggle-data/test_images/f2320b9e1197.png
#   inflating: kaggle-data/test_images/d7532b579b2b.png
#   inflating: kaggle-data/test_images/0d1c7806f918.png
#   inflating: kaggle-data/test_images/f0848f9ccf92.png
#   inflating: kaggle-data/test_images/4d00167f2d05.png
#   inflating: kaggle-data/test_images/445fec0912db.png
#   inflating: kaggle-data/test_images/c6c76cf68bb8.png
#   inflating: kaggle-data/test_images/652a7d1e42cf.png
#   inflating: kaggle-data/test_images/5b04aa895c31.png
#   inflating: kaggle-data/test_images/d57bdb46e998.png
#   inflating: kaggle-data/test_images/401279eb879a.png
#   inflating: kaggle-data/test_images/6c3053baeb67.png
#   inflating: kaggle-data/test_images/3d83eba14bd2.png
#   inflating: kaggle-data/test_images/b6937fc5672f.png
#   inflating: kaggle-data/test_images/91b81018ff9d.png
#   inflating: kaggle-data/test_images/ade59f8a4564.png
#   inflating: kaggle-data/test_images/ed59b7d44223.png
#   inflating: kaggle-data/test_images/0f1a967313c3.png
#   inflating: kaggle-data/test_images/2a18955eeb41.png
#   inflating: kaggle-data/test_images/ef5f4ffdd75c.png
#   inflating: kaggle-data/test_images/50dab20a4ad4.png
#   inflating: kaggle-data/test_images/1d7c4c12769e.png
#   inflating: kaggle-data/test_images/abd992633744.png
#   inflating: kaggle-data/test_images/3943a494fb0d.png
#   inflating: kaggle-data/test_images/411ee15ad4cf.png
#   inflating: kaggle-data/test_images/48cc693a081d.png
#   inflating: kaggle-data/test_images/981115ef58ed.png
#   inflating: kaggle-data/test_images/490c7597892e.png
#   inflating: kaggle-data/test_images/18f09deddab7.png
#   inflating: kaggle-data/test_images/ef39106db910.png
#   inflating: kaggle-data/test_images/f96fecb16957.png
#   inflating: kaggle-data/test_images/e29765ebf3bc.png
#   inflating: kaggle-data/test_images/f75b65c8cc4c.png
#   inflating: kaggle-data/test_images/e5987d9e2a11.png
#   inflating: kaggle-data/test_images/93cbafc82f37.png
#   inflating: kaggle-data/test_images/967b01064b9c.png
#   inflating: kaggle-data/test_images/4890c8e4f897.png
#   inflating: kaggle-data/test_images/c69386aeafd3.png
#   inflating: kaggle-data/test_images/db6d64fc74e9.png
#   inflating: kaggle-data/test_images/5edf6828c280.png
#   inflating: kaggle-data/test_images/f36969f69b4f.png
#   inflating: kaggle-data/test_images/2f9a5d2c4ee5.png
#   inflating: kaggle-data/test_images/d481ddad16f2.png
#   inflating: kaggle-data/test_images/a6533f3144ba.png
#   inflating: kaggle-data/test_images/7959bb5d9fa2.png
#   inflating: kaggle-data/test_images/a9bc8e153c30.png
#   inflating: kaggle-data/test_images/2917c28c46d5.png
#   inflating: kaggle-data/test_images/c72492c66aa4.png
#   inflating: kaggle-data/test_images/b28619c58d35.png
#   inflating: kaggle-data/test_images/95e13f31b451.png
#   inflating: kaggle-data/test_images/98b2af334295.png
#   inflating: kaggle-data/test_images/6a4936e83256.png
#   inflating: kaggle-data/test_images/4306b1965385.png
#   inflating: kaggle-data/test_images/009c019a7309.png
#   inflating: kaggle-data/test_images/8798cccbcb0d.png
#   inflating: kaggle-data/test_images/af9d45e2f834.png
#   inflating: kaggle-data/test_images/c5e5fb775899.png
#   inflating: kaggle-data/test_images/45ca3fb3bfc5.png
#   inflating: kaggle-data/test_images/28cba3df4fa9.png
#   inflating: kaggle-data/test_images/01c31b10ab99.png
#   inflating: kaggle-data/test_images/ff64897ac0d8.png
#   inflating: kaggle-data/test_images/d87e5a77a830.png
#   inflating: kaggle-data/test_images/1282d33e6fbc.png
#   inflating: kaggle-data/test_images/4df7349f0806.png
#   inflating: kaggle-data/test_images/94fac9bf79e0.png
#   inflating: kaggle-data/test_images/5d6b9a2fddbf.png
#   inflating: kaggle-data/test_images/fab7d8e8a1fa.png
#   inflating: kaggle-data/test_images/d13d82ddc158.png
#   inflating: kaggle-data/test_images/98c2c42a0317.png
#   inflating: kaggle-data/test_images/462507c543fb.png
#   inflating: kaggle-data/test_images/3c6bee77688a.png
#   inflating: kaggle-data/test_images/391b1802dfb5.png
#   inflating: kaggle-data/test_images/1ab40e2386ea.png
#   inflating: kaggle-data/test_images/78bdd1ecee00.png
#   inflating: kaggle-data/test_images/85035afa9b10.png
#   inflating: kaggle-data/test_images/f8b184ad0701.png
#   inflating: kaggle-data/test_images/5ca89ec3c507.png
#   inflating: kaggle-data/test_images/bf599a93ca9b.png
#   inflating: kaggle-data/test_images/7d6ea897ee30.png
#   inflating: kaggle-data/test_images/17f0a333f224.png
#   inflating: kaggle-data/test_images/228e7cf174ae.png
#   inflating: kaggle-data/test_images/f3bebccd8f01.png
#   inflating: kaggle-data/test_images/a807402308f2.png
#   inflating: kaggle-data/test_images/a8798ba9d196.png
#   inflating: kaggle-data/test_images/4def7bc721a9.png
#   inflating: kaggle-data/test_images/96c3445bf5cd.png
#   inflating: kaggle-data/test_images/9f90ceaacec9.png
#   inflating: kaggle-data/test_images/21715aad6f7b.png
#   inflating: kaggle-data/test_images/113971387d87.png
#   inflating: kaggle-data/test_images/6833ab2550c9.png
#   inflating: kaggle-data/test_images/6e19f08344ed.png
#   inflating: kaggle-data/test_images/48b280688d0d.png
#   inflating: kaggle-data/test_images/896c75533897.png
#   inflating: kaggle-data/test_images/a0cc05ce59fa.png
#   inflating: kaggle-data/test_images/4ddfe4a87b11.png
#   inflating: kaggle-data/test_images/3dc26a50270e.png
#   inflating: kaggle-data/test_images/7754a10b07ae.png
#   inflating: kaggle-data/test_images/c70ef770980e.png
#   inflating: kaggle-data/test_images/f320b5f7f5b5.png
#   inflating: kaggle-data/test_images/cc232dbbb4d1.png
#   inflating: kaggle-data/test_images/17403c0714f1.png
#   inflating: kaggle-data/test_images/c849b220a7b6.png
#   inflating: kaggle-data/test_images/22c9f6694a99.png
#   inflating: kaggle-data/test_images/b70b29ad9e23.png
#   inflating: kaggle-data/test_images/f3e5159e0b2d.png
#   inflating: kaggle-data/test_images/6eb52b81fa50.png
#   inflating: kaggle-data/test_images/95485b752436.png
#   inflating: kaggle-data/test_images/9a514aa26e2f.png
#   inflating: kaggle-data/test_images/6a0f21edb0d8.png
#   inflating: kaggle-data/test_images/16d36c3d0553.png
#   inflating: kaggle-data/test_images/80921264504c.png
#   inflating: kaggle-data/test_images/689d028fe647.png
#   inflating: kaggle-data/test_images/f68ada6a0892.png
#   inflating: kaggle-data/test_images/91fb0a2a63fd.png
#   inflating: kaggle-data/test_images/5b931245433c.png
#   inflating: kaggle-data/test_images/b9d2e411d7a5.png
#   inflating: kaggle-data/test_images/128b94971423.png
#   inflating: kaggle-data/test_images/8fc74bd50fcb.png
#   inflating: kaggle-data/test_images/ddc65711db04.png
#   inflating: kaggle-data/test_images/07685fac659a.png
#   inflating: kaggle-data/test_images/7d7cbd5ee1b3.png
#   inflating: kaggle-data/test_images/88e0bd76f4c9.png
#   inflating: kaggle-data/test_images/7015c532679c.png
#   inflating: kaggle-data/test_images/ce3ac82b2824.png
#   inflating: kaggle-data/test_images/132e1876157b.png
#   inflating: kaggle-data/test_images/95c3558dc279.png
#   inflating: kaggle-data/test_images/c11b3794d4e9.png
#   inflating: kaggle-data/test_images/5f06b715ea24.png
#   inflating: kaggle-data/test_images/308924f570d7.png
#   inflating: kaggle-data/test_images/5595883f47f0.png
#   inflating: kaggle-data/test_images/b17545486692.png
#   inflating: kaggle-data/test_images/16ae52b6ac9b.png
#   inflating: kaggle-data/test_images/5177461f5339.png
#   inflating: kaggle-data/test_images/7af3af7910a4.png
#   inflating: kaggle-data/test_images/0b88274d5d7d.png
#   inflating: kaggle-data/test_images/6124e6a4ad00.png
#   inflating: kaggle-data/test_images/1ba29885e4ce.png
#   inflating: kaggle-data/test_images/f9f1cd9ed16c.png
#   inflating: kaggle-data/test_images/791fbce04aa5.png
#   inflating: kaggle-data/test_images/6dce3f20de26.png
#   inflating: kaggle-data/test_images/9b325a96f41a.png
#   inflating: kaggle-data/test_images/ab2daf10fd97.png
#   inflating: kaggle-data/test_images/c2ab32a760b6.png
#   inflating: kaggle-data/test_images/9d19500e74c9.png
#   inflating: kaggle-data/test_images/fde8778182af.png
#   inflating: kaggle-data/test_images/ee6e56f02740.png
#   inflating: kaggle-data/test_images/ea8e9a3144e0.png
#   inflating: kaggle-data/test_images/2630d7731c72.png
#   inflating: kaggle-data/test_images/4b83fb74c2a7.png
#   inflating: kaggle-data/test_images/bf441174ad79.png
#   inflating: kaggle-data/test_images/e04b4316c2a1.png
#   inflating: kaggle-data/test_images/06daa7390238.png
#   inflating: kaggle-data/test_images/cf94420fc02c.png
#   inflating: kaggle-data/test_images/130887394f97.png
#   inflating: kaggle-data/test_images/a3e5281f3158.png
#   inflating: kaggle-data/test_images/dc7b66c705d7.png
#   inflating: kaggle-data/test_images/e3eaf3d12ad4.png
#   inflating: kaggle-data/test_images/14a4f23b07a5.png
#   inflating: kaggle-data/test_images/7c1d86c79903.png
#   inflating: kaggle-data/test_images/83c31eeeca0e.png
#   inflating: kaggle-data/test_images/d655d099f8d6.png
#   inflating: kaggle-data/test_images/c867b4547f66.png
#   inflating: kaggle-data/test_images/d557cff45218.png
#   inflating: kaggle-data/test_images/682baef89ab6.png
#   inflating: kaggle-data/test_images/a512464b26bf.png
#   inflating: kaggle-data/test_images/7744ab973027.png
#   inflating: kaggle-data/test_images/d4266ee268a8.png
#   inflating: kaggle-data/test_images/66304c1099a0.png
#   inflating: kaggle-data/test_images/5b18feb15d84.png
#   inflating: kaggle-data/test_images/100d678b8125.png
#   inflating: kaggle-data/test_images/6a27a25f7a0c.png
#   inflating: kaggle-data/test_images/0e107399795b.png
#   inflating: kaggle-data/test_images/ad24860aee94.png
#   inflating: kaggle-data/test_images/98b46d9f4731.png
#   inflating: kaggle-data/test_images/0fb31b7aef5f.png
#   inflating: kaggle-data/test_images/09b5e952f996.png
#   inflating: kaggle-data/test_images/cb2eaa6e87ad.png
#   inflating: kaggle-data/test_images/8cbefbaed16e.png
#   inflating: kaggle-data/test_images/ab3050f000f5.png
#   inflating: kaggle-data/test_images/f5ebdedbba98.png
#   inflating: kaggle-data/test_images/1d2354eba61d.png
#   inflating: kaggle-data/test_images/a7c338c946be.png
#   inflating: kaggle-data/test_images/be640164686b.png
#   inflating: kaggle-data/test_images/9c73a69a7911.png
#   inflating: kaggle-data/test_images/bee2621d5a8e.png
#   inflating: kaggle-data/test_images/2430807dfad5.png
#   inflating: kaggle-data/test_images/cf98137e0faa.png
#   inflating: kaggle-data/test_images/b79bc424675f.png
#   inflating: kaggle-data/test_images/f3135d8ed877.png
#   inflating: kaggle-data/test_images/2c76697bd479.png
#   inflating: kaggle-data/test_images/5dc52ff46300.png
#   inflating: kaggle-data/test_images/cf95d13f210a.png
#   inflating: kaggle-data/test_images/e97517f83449.png
#   inflating: kaggle-data/test_images/77283954f311.png
#   inflating: kaggle-data/test_images/7007d3ba7e79.png
#   inflating: kaggle-data/test_images/a2183cf3a237.png
#   inflating: kaggle-data/test_images/abd5b64eb7c8.png
#   inflating: kaggle-data/test_images/19f165a25974.png
#   inflating: kaggle-data/test_images/4defa0f6e0aa.png
#   inflating: kaggle-data/test_images/8affa9a1fecd.png
#   inflating: kaggle-data/test_images/be99a17d1158.png
#   inflating: kaggle-data/test_images/77f1ffe777b7.png
#   inflating: kaggle-data/test_images/55c5356d96f8.png
#   inflating: kaggle-data/test_images/ad25a4f5beba.png
#   inflating: kaggle-data/test_images/adb38b7630c7.png
#   inflating: kaggle-data/test_images/b1f69a5b75d4.png
#   inflating: kaggle-data/test_images/9a9091fd7806.png
#   inflating: kaggle-data/test_images/d5e760a949b9.png
#   inflating: kaggle-data/test_images/40b4ece7bd32.png
#   inflating: kaggle-data/test_images/3393ee9e7f29.png
#   inflating: kaggle-data/test_images/3db49b4d5a7f.png
#   inflating: kaggle-data/test_images/619ce2c77917.png
#   inflating: kaggle-data/test_images/3c297a4f0464.png
#   inflating: kaggle-data/test_images/60849fa4a14a.png
#   inflating: kaggle-data/test_images/8208638fc7cf.png
#   inflating: kaggle-data/test_images/0d1610cda7fc.png
#   inflating: kaggle-data/test_images/fc66648f758e.png
#   inflating: kaggle-data/test_images/6d0df0ec5fd7.png
#   inflating: kaggle-data/test_images/938a59f04582.png
#   inflating: kaggle-data/test_images/ef10428bec8e.png
#   inflating: kaggle-data/test_images/57d5d0d42cac.png
#   inflating: kaggle-data/test_images/c320df3fe094.png
#   inflating: kaggle-data/test_images/8bdd3a1895c8.png
#   inflating: kaggle-data/test_images/9ae71f3f62d1.png
#   inflating: kaggle-data/test_images/85601f22d90d.png
#   inflating: kaggle-data/test_images/bccb2c2c4216.png
#   inflating: kaggle-data/test_images/e9602a2d3044.png
#   inflating: kaggle-data/test_images/983f2756d8be.png
#   inflating: kaggle-data/test_images/b1ea863519a7.png
#   inflating: kaggle-data/test_images/b40863d24767.png
#   inflating: kaggle-data/test_images/b0c55927f712.png
#   inflating: kaggle-data/test_images/badf9d11fe77.png
#   inflating: kaggle-data/test_images/9215a3ce482b.png
#   inflating: kaggle-data/test_images/e1a9cafeb308.png
#   inflating: kaggle-data/test_images/d9b846ab7972.png
#   inflating: kaggle-data/test_images/7d2243c508d8.png
#   inflating: kaggle-data/test_images/79adfdcb827f.png
#   inflating: kaggle-data/test_images/c0f6ebbff5dd.png
#   inflating: kaggle-data/test_images/2677d5c9983e.png
#   inflating: kaggle-data/test_images/53be22c72713.png
#   inflating: kaggle-data/test_images/2893b2a3cdfe.png
#   inflating: kaggle-data/test_images/4944b1de8817.png
#   inflating: kaggle-data/test_images/4d8e6a111b56.png
#   inflating: kaggle-data/test_images/607f40adf8b1.png
#   inflating: kaggle-data/test_images/8bb4dfa61806.png
#   inflating: kaggle-data/test_images/9df628dd2d68.png
#   inflating: kaggle-data/test_images/8f4ffa0d4f74.png
#   inflating: kaggle-data/test_images/1822b6c60784.png
#   inflating: kaggle-data/test_images/b0d2c5ac27ed.png
#   inflating: kaggle-data/test_images/7eb119b81d16.png
#   inflating: kaggle-data/test_images/b5c4cae30f91.png
#   inflating: kaggle-data/test_images/1d5a1d9fe2cb.png
#   inflating: kaggle-data/test_images/8fc5d55a4ece.png
#   inflating: kaggle-data/test_images/43e0368e857b.png
#   inflating: kaggle-data/test_images/944678405e5e.png
#   inflating: kaggle-data/test_images/0ad36156ad5d.png
#   inflating: kaggle-data/test_images/cbde1c64f27e.png
#   inflating: kaggle-data/test_images/4fa9722572c0.png
#   inflating: kaggle-data/test_images/167d9edb5cc1.png
#   inflating: kaggle-data/test_images/c883b941e7d7.png
#   inflating: kaggle-data/test_images/dcee11470733.png
#   inflating: kaggle-data/test_images/6a1ee951c1d5.png
#   inflating: kaggle-data/test_images/079e029f3b2e.png
#   inflating: kaggle-data/test_images/61cd9c25c7d3.png
#   inflating: kaggle-data/test_images/e0ccaed5f4fc.png
#   inflating: kaggle-data/test_images/4bf97a2f0398.png
#   inflating: kaggle-data/test_images/933724df128e.png
#   inflating: kaggle-data/test_images/ee506d853270.png
#   inflating: kaggle-data/test_images/daa2d1d05f49.png
#   inflating: kaggle-data/test_images/4efa03e7d043.png
#   inflating: kaggle-data/test_images/9f1af957139f.png
#   inflating: kaggle-data/test_images/dff147e8c2f9.png
#   inflating: kaggle-data/test_images/8b27d742f971.png
#   inflating: kaggle-data/test_images/d23aa310a873.png
#   inflating: kaggle-data/test_images/c03b523cfb2d.png
#   inflating: kaggle-data/test_images/5d3d0306074c.png
#   inflating: kaggle-data/test_images/cb004a78aecf.png
#   inflating: kaggle-data/test_images/586eba507c88.png
#   inflating: kaggle-data/test_images/ba8e74535796.png
#   inflating: kaggle-data/test_images/446d2a4606bf.png
#   inflating: kaggle-data/test_images/44c7a0b9820f.png
#   inflating: kaggle-data/test_images/e319bce1d9ad.png
#   inflating: kaggle-data/test_images/f7113d580492.png
#   inflating: kaggle-data/test_images/e2300fd74ccc.png
#   inflating: kaggle-data/test_images/5544449ac18d.png
#   inflating: kaggle-data/test_images/a14c98b20437.png
#   inflating: kaggle-data/test_images/f44fd938c664.png
#   inflating: kaggle-data/test_images/57fa1bc682b6.png
#   inflating: kaggle-data/test_images/8c6ccbe00895.png
#   inflating: kaggle-data/test_images/82515c8bfd5e.png
#   inflating: kaggle-data/test_images/ce588daddf8d.png
#   inflating: kaggle-data/test_images/46c4fb9164dc.png
#   inflating: kaggle-data/test_images/c582e76be4a6.png
#   inflating: kaggle-data/test_images/8e4cf64ec035.png
#   inflating: kaggle-data/test_images/c0cb34b0f29f.png
#   inflating: kaggle-data/test_images/f1178112a435.png
#   inflating: kaggle-data/test_images/d99a7151297d.png
#   inflating: kaggle-data/test_images/49897ae73aa9.png
#   inflating: kaggle-data/test_images/a2319c2af727.png
#   inflating: kaggle-data/test_images/fd8e6b0b2e45.png
#   inflating: kaggle-data/test_images/75b6ffa63525.png
#   inflating: kaggle-data/test_images/366e5c14a7d8.png
#   inflating: kaggle-data/test_images/9ed194d1942c.png
#   inflating: kaggle-data/test_images/1136833be435.png
#   inflating: kaggle-data/test_images/ad7675128e0c.png
#   inflating: kaggle-data/test_images/d66b9c127924.png
#   inflating: kaggle-data/test_images/c6340f6782f3.png
#   inflating: kaggle-data/test_images/bb0f83e7224f.png
#   inflating: kaggle-data/test_images/31825463d1e3.png
#   inflating: kaggle-data/test_images/7b03611c6d88.png
#   inflating: kaggle-data/test_images/0ddb0dbbef76.png
#   inflating: kaggle-data/test_images/627997ab6ba3.png
#   inflating: kaggle-data/test_images/b22d649a343a.png
#   inflating: kaggle-data/test_images/da68a7779f0d.png
#   inflating: kaggle-data/test_images/cac200729b8c.png
#   inflating: kaggle-data/test_images/5a6a2c8cdd35.png
#   inflating: kaggle-data/test_images/de2bfc6ae8dc.png
#   inflating: kaggle-data/test_images/512beaada8f0.png
#   inflating: kaggle-data/test_images/948c75fbe02f.png
#   inflating: kaggle-data/test_images/17fb965efdf3.png
#   inflating: kaggle-data/test_images/ffdc2152d455.png
#   inflating: kaggle-data/test_images/4f857f0e33e5.png
#   inflating: kaggle-data/test_images/58392bb56fad.png
#   inflating: kaggle-data/test_images/1466c7e5936e.png
#   inflating: kaggle-data/test_images/86c179395e2b.png
#   inflating: kaggle-data/test_images/a5ea92b7864c.png
#   inflating: kaggle-data/test_images/ad225d153500.png
#   inflating: kaggle-data/test_images/cbdc19b70634.png
#   inflating: kaggle-data/test_images/0e428b886e07.png
#   inflating: kaggle-data/test_images/3c2796e8e8ff.png
#   inflating: kaggle-data/test_images/1388399910c7.png
#   inflating: kaggle-data/test_images/d3e10a38cefb.png
#   inflating: kaggle-data/test_images/97c4f207ae56.png
#   inflating: kaggle-data/test_images/b0767b7577e4.png
#   inflating: kaggle-data/test_images/464ee4a542b0.png
#   inflating: kaggle-data/test_images/437fa52cb1cb.png
#   inflating: kaggle-data/test_images/8bbef4ac9702.png
#   inflating: kaggle-data/test_images/557be0cf8e49.png
#   inflating: kaggle-data/test_images/5276ab33b7b0.png
#   inflating: kaggle-data/test_images/3dfe134d5d1c.png
#   inflating: kaggle-data/test_images/c4cfcc09fdf1.png
#   inflating: kaggle-data/test_images/2e4c87ecc92c.png
#   inflating: kaggle-data/test_images/73b897339735.png
#   inflating: kaggle-data/test_images/c8beb20d5a63.png
#   inflating: kaggle-data/test_images/01c5ba195207.png
#   inflating: kaggle-data/test_images/d29354018b36.png
#   inflating: kaggle-data/test_images/8a1791bd2bb0.png
#   inflating: kaggle-data/test_images/82566de7f4d1.png
#   inflating: kaggle-data/test_images/51323e9d2070.png
#   inflating: kaggle-data/test_images/8e83a8ae27cf.png
#   inflating: kaggle-data/test_images/1927c7ed6570.png
#   inflating: kaggle-data/test_images/8fb196f59171.png
#   inflating: kaggle-data/test_images/b436e2bfeabe.png
#   inflating: kaggle-data/test_images/bf0a40de1790.png
#   inflating: kaggle-data/test_images/d7a16a05f86e.png
#   inflating: kaggle-data/test_images/61ff3873c036.png
#   inflating: kaggle-data/test_images/8c45490f701a.png
#   inflating: kaggle-data/test_images/417f1709a8a2.png
#   inflating: kaggle-data/test_images/cccaeed0bc15.png
#   inflating: kaggle-data/test_images/5a66a5abdec6.png
#   inflating: kaggle-data/test_images/643ff5d1f90f.png
#   inflating: kaggle-data/test_images/4578ed5eeb9f.png
#   inflating: kaggle-data/test_images/1a6b7f58d488.png
#   inflating: kaggle-data/test_images/3099467aeef2.png
#   inflating: kaggle-data/test_images/ca2521ce3704.png
#   inflating: kaggle-data/test_images/2f346c794823.png
#   inflating: kaggle-data/test_images/71291389a55d.png
#   inflating: kaggle-data/test_images/7c10eeb5f1ee.png
#   inflating: kaggle-data/test_images/1b79278c8cb5.png
#   inflating: kaggle-data/test_images/2ea138c85bb1.png
#   inflating: kaggle-data/test_images/600afae2d4e9.png
#   inflating: kaggle-data/test_images/153a1a1157d8.png
#   inflating: kaggle-data/test_images/65153f9ad387.png
#   inflating: kaggle-data/test_images/448c1f328542.png
#   inflating: kaggle-data/test_images/35c2442a20dc.png
#   inflating: kaggle-data/test_images/c3214eb3f870.png
#   inflating: kaggle-data/test_images/e73737111c4e.png
#   inflating: kaggle-data/test_images/69f0ca93349a.png
#   inflating: kaggle-data/test_images/b9896cdaa409.png
#   inflating: kaggle-data/test_images/9ede102f5e7b.png
#   inflating: kaggle-data/test_images/ac1ead3c51c6.png
#   inflating: kaggle-data/test_images/b4aa74fa7811.png
#   inflating: kaggle-data/test_images/0a262e8b2a5a.png
#   inflating: kaggle-data/test_images/349ab243e75c.png
#   inflating: kaggle-data/test_images/fac5beea82bd.png
#   inflating: kaggle-data/test_images/872d2097a7ad.png
#   inflating: kaggle-data/test_images/a94217c6d4fb.png
#   inflating: kaggle-data/test_images/024d0a225db1.png
#   inflating: kaggle-data/test_images/d1edebb87566.png
#   inflating: kaggle-data/test_images/35dbd229cfa2.png
#   inflating: kaggle-data/test_images/64d749faea54.png
#   inflating: kaggle-data/test_images/d04d1e8302c1.png
#   inflating: kaggle-data/test_images/8142cc87ebb9.png
#   inflating: kaggle-data/test_images/8930d35c9076.png
#   inflating: kaggle-data/test_images/c9725a732b15.png
#   inflating: kaggle-data/test_images/0ed192cd67a2.png
#   inflating: kaggle-data/test_images/ae1cc896a422.png
#   inflating: kaggle-data/test_images/5598165adbff.png
#   inflating: kaggle-data/test_images/c689594e1738.png
#   inflating: kaggle-data/test_images/4a01c849bdeb.png
#   inflating: kaggle-data/test_images/8214256b4e51.png
#   inflating: kaggle-data/test_images/2047c76a05da.png
#   inflating: kaggle-data/test_images/e59c5a52ab4c.png
#   inflating: kaggle-data/test_images/17b08e34f0ed.png
#   inflating: kaggle-data/test_images/c85bc4a45f7c.png
#   inflating: kaggle-data/test_images/59e7f9e69044.png
#   inflating: kaggle-data/test_images/bb53d6785e8a.png
#   inflating: kaggle-data/test_images/afc9e5eb7158.png
#   inflating: kaggle-data/test_images/10205b883f26.png
#   inflating: kaggle-data/test_images/7889e79f59f6.png
#   inflating: kaggle-data/test_images/29749f55270d.png
#   inflating: kaggle-data/test_images/096d6bb6546b.png
#   inflating: kaggle-data/test_images/edae318f4942.png
#   inflating: kaggle-data/test_images/b8e0fb561c0c.png
#   inflating: kaggle-data/test_images/c23ba42c5251.png
#   inflating: kaggle-data/test_images/148e913a3cb7.png
#   inflating: kaggle-data/test_images/ffa73465b705.png
#   inflating: kaggle-data/test_images/cc95391f2576.png
#   inflating: kaggle-data/test_images/1ca7ecbd29fc.png
#   inflating: kaggle-data/test_images/83cfacba2dd7.png
#   inflating: kaggle-data/test_images/3c1d461434eb.png
#   inflating: kaggle-data/test_images/3a1bdff4e304.png
#   inflating: kaggle-data/test_images/764e6ea355ac.png
#   inflating: kaggle-data/test_images/8927a914c9c8.png
#   inflating: kaggle-data/test_images/4c70b2944d9e.png
#   inflating: kaggle-data/test_images/8a2b969112a7.png
#   inflating: kaggle-data/test_images/901028c2b54f.png
#   inflating: kaggle-data/test_images/172eb75bc414.png
#   inflating: kaggle-data/test_images/9eabe2bdf1e9.png
#   inflating: kaggle-data/test_images/2412b2c0e74a.png
#   inflating: kaggle-data/test_images/71047d5e7299.png
#   inflating: kaggle-data/test_images/494db7a542a8.png
#   inflating: kaggle-data/test_images/ae61b6385750.png
#   inflating: kaggle-data/test_images/bca38b014cdd.png
#   inflating: kaggle-data/test_images/bfd3dcc96967.png
#   inflating: kaggle-data/test_images/0c7e66a53ce3.png
#   inflating: kaggle-data/test_images/93220677378c.png
#   inflating: kaggle-data/test_images/3040ae4067b0.png
#   inflating: kaggle-data/test_images/fa98490bc13c.png
#   inflating: kaggle-data/test_images/6a4ab4927ee7.png
#   inflating: kaggle-data/test_images/f360627bb76b.png
#   inflating: kaggle-data/test_images/d087cc94e803.png
#   inflating: kaggle-data/test_images/4fdd1ca8bd89.png
# ...
#   inflating: aug_train_images/6cfb7b44ef6f_4.png
#   inflating: aug_train_images/3ac3fbfca7d4_3.png
#   inflating: aug_train_images/1a7e3356b39c_1.png
#   inflating: aug_train_images/52ae917fcea4_0.png
#   inflating: aug_train_images/1df3e03a8f5f_1.png
#   inflating: aug_train_images/c9d42d7534e0_0.png
#   inflating: aug_train_images/37c4dfe03aba_1.png
#   inflating: aug_train_images/ead23cc922ed_3.png
#   inflating: aug_train_images/8000a6b97a84.png
#   inflating: aug_train_images/8bdb891661a8_0.png
#   inflating: aug_train_images/a19ecd0a706e_3.png
#   inflating: aug_train_images/1bf30c84bbad_2.png
#   inflating: aug_train_images/b49b2fac2514_4.png
#   inflating: aug_train_images/0cb14014117d_7.png
#   inflating: aug_train_images/4478b870e549_0.png
#   inflating: aug_train_images/785777558f05_1.png
#   inflating: aug_train_images/66a0bf258013_4.png
#   inflating: aug_train_images/c5a9ebef1517_0.png
#   inflating: aug_train_images/1bf30c84bbad_4.png
#   inflating: aug_train_images/c5bec7f1e5f3.png
#   inflating: aug_train_images/91f3c4c1e72b.png
#   inflating: aug_train_images/4a7dc013e802_2.png
#   inflating: aug_train_images/4b6cb0bcfd44.png
#   inflating: aug_train_images/cd29c88c9e36_0.png
#   inflating: aug_train_images/b9127e38d9b9.png
#   inflating: aug_train_images/4da2961e62fe_0.png
#   inflating: aug_train_images/1caba2fb38f6.png
#   inflating: aug_train_images/9fefe2b44795_0.png
#   inflating: aug_train_images/6a244e855d0e.png
#   inflating: aug_train_images/c9ea9d5eab65_5.png
#   inflating: aug_train_images/9ad92f1c1542.png
#   inflating: aug_train_images/0bf37ca3156a_0.png
#   inflating: aug_train_images/bc23f74e14dd.png
#   inflating: aug_train_images/0cb14014117d.png
#   inflating: aug_train_images/513b0a4651fa_2.png
#   inflating: aug_train_images/bd269a1f0e4d_2.png
#   inflating: aug_train_images/ae58ccb5905e.png
#   inflating: aug_train_images/5eb311bcb5f9.png
#   inflating: aug_train_images/b4f41b5bf0ef_0.png
#   inflating: aug_train_images/a2ddabee14e9_0.png
#   inflating: aug_train_images/916915f01e17.png
#   inflating: aug_train_images/ff8a0b45c789_1.png
#   inflating: aug_train_images/76e6a9238570.png
#   inflating: aug_train_images/8db2ce991101.png
#   inflating: aug_train_images/e62490b7d0e9_1.png
#   inflating: aug_train_images/8bed09514c3b_0.png
#   inflating: aug_train_images/d844a7252f4e.png
#   inflating: aug_train_images/8bf2d925dc0c.png
#   inflating: aug_train_images/38f1901f214a.png
#   inflating: aug_train_images/bf8092e4001d_3.png
#   inflating: aug_train_images/1c4f3aa4df06_3.png
#   inflating: aug_train_images/42b93b574f23_0.png
#   inflating: aug_train_images/272d9c043c81.png
#   inflating: aug_train_images/98104c8c67eb_0.png
#   inflating: aug_train_images/22a6da005395.png
#   inflating: aug_train_images/aa31bc6b8f4d_0.png
#   inflating: aug_train_images/3a6e9730b298.png
#   inflating: aug_train_images/69fff98cb32a_1.png
#   inflating: aug_train_images/6c2555a9cae4.png
#   inflating: aug_train_images/0c7e82daf5a0.png
#   inflating: aug_train_images/a01024054596_1.png
#   inflating: aug_train_images/e3ec668f6fad.png
#   inflating: aug_train_images/697538183db5_3.png
#   inflating: aug_train_images/4409965eb2a4.png
#   inflating: aug_train_images/99c626e58464.png
#   inflating: aug_train_images/cd66754e1b3b.png
#   inflating: aug_train_images/44e0d56e9d42.png
#   inflating: aug_train_images/8a234d68b27e_7.png
#   inflating: aug_train_images/9859e2a6cc24_2.png
#   inflating: aug_train_images/e85d410d6836_0.png
#   inflating: aug_train_images/a476fd984005_0.png
#   inflating: aug_train_images/2241b7e90782_0.png
#   inflating: aug_train_images/3218a6d8eb2c_2.png
#   inflating: aug_train_images/7347f5133a6a_0.png
#   inflating: aug_train_images/ca891d37a43c.png
#   inflating: aug_train_images/c40976189f22.png
#   inflating: aug_train_images/49419f8d5cb4.png
#   inflating: aug_train_images/c1e6fa1ad314.png
#   inflating: aug_train_images/8d8aca52c07b_0.png
#   inflating: aug_train_images/4246ed634f25_0.png
#   inflating: aug_train_images/b09101adb478.png
#   inflating: aug_train_images/aa31bc6b8f4d.png
#   inflating: aug_train_images/c8823cdaf7fa.png
#   inflating: aug_train_images/1116271db4ea_0.png
#   inflating: aug_train_images/28f98cfe3858_0.png
#   inflating: aug_train_images/e93394175a19_7.png
#   inflating: aug_train_images/39f8935185e6.png
#   inflating: aug_train_images/0eced86c9db8.png
#   inflating: aug_train_images/687759336b0d_1.png
#   inflating: aug_train_images/05195a3db5e2.png
#   inflating: aug_train_images/c18a006f7f1d.png
#   inflating: aug_train_images/76e589911303.png
#   inflating: aug_train_images/613bacb35c05_0.png
#   inflating: aug_train_images/bd5013540a13_2.png
#   inflating: aug_train_images/873fe0404d6e_0.png
#   inflating: aug_train_images/5090917a2676_2.png
#   inflating: aug_train_images/3ca637fddd56_2.png
#   inflating: aug_train_images/37c4dfe03aba_0.png
#   inflating: aug_train_images/a9e984b57556_7.png
#   inflating: aug_train_images/87d46b1cc4e9.png
#   inflating: aug_train_images/d51b3fe0fa1b.png
#   inflating: aug_train_images/23148a40ecb0_0.png
#   inflating: aug_train_images/1a90fad9ffa2_0.png
#   inflating: aug_train_images/8201cab8322d.png
#   inflating: aug_train_images/650fbed3fdca_0.png
#   inflating: aug_train_images/0e0fc1d9810c_0.png
#   inflating: aug_train_images/abf09c44d5f4_0.png
#   inflating: aug_train_images/7d3835e4e63a_0.png
#   inflating: aug_train_images/4818672273af_0.png
#   inflating: aug_train_images/4cfd22ae43d4.png
#   inflating: aug_train_images/4d47300e3ddb_1.png
#   inflating: aug_train_images/35d6c4c50072.png
#   inflating: aug_train_images/7f2123bc89a3.png
#   inflating: aug_train_images/cca626a0e19a_0.png
#   inflating: aug_train_images/28a4d00927b7_0.png
#   inflating: aug_train_images/4189d4e631ec_0.png
#   inflating: aug_train_images/fe2df69676cf_0.png
#   inflating: aug_train_images/86410aa13b3e.png
#   inflating: aug_train_images/edceb0657d77.png
#   inflating: aug_train_images/fea14b3d44b0_3.png
#   inflating: aug_train_images/bb45257258cc_2.png
#   inflating: aug_train_images/e66ad813a508.png
#   inflating: aug_train_images/6e73acb2cf60_2.png
#   inflating: aug_train_images/c6c2bad91f23.png
#   inflating: aug_train_images/eb1d37b71fd1_0.png
#   inflating: aug_train_images/15cd5f52d300_0.png
#   inflating: aug_train_images/1b329a127307.png
#   inflating: aug_train_images/55034b1dbff2.png
#   inflating: aug_train_images/2923971566fe.png
#   inflating: aug_train_images/a32b5ce3d48a_3.png
#   inflating: aug_train_images/7a9f45fdf29b.png
#   inflating: aug_train_images/5b068765e846_2.png
#   inflating: aug_train_images/9ae54843c69a.png
#   inflating: aug_train_images/aba3063c5413_2.png
#   inflating: aug_train_images/bba38f2294a3.png
#   inflating: aug_train_images/5b804948e35f_0.png
#   inflating: aug_train_images/7347f5133a6a_1.png
#   inflating: aug_train_images/6fbaaf8eb67a.png
#   inflating: aug_train_images/c9ea9d5eab65_0.png
#   inflating: aug_train_images/eda1d75cbcf0.png
#   inflating: aug_train_images/c1896142a20a_3.png
#   inflating: aug_train_images/21d18b022429_4.png
#   inflating: aug_train_images/80e7cc0a0649_1.png
#   inflating: aug_train_images/c3cd0200df79_3.png
#   inflating: aug_train_images/76e6a9238570_0.png
#   inflating: aug_train_images/5723d0ec895e_0.png
#   inflating: aug_train_images/513b0a4651fa_3.png
#   inflating: aug_train_images/8dfa629ca74e_0.png
#   inflating: aug_train_images/89b725411cee.png
#   inflating: aug_train_images/c027e5482e8c_3.png
#   inflating: aug_train_images/8329e80c10ac.png
#   inflating: aug_train_images/bcb0498ed2c1.png
#   inflating: aug_train_images/d4bc001f7224.png
#   inflating: aug_train_images/82ac8463fadd_0.png
#   inflating: aug_train_images/eed4afc8ec83_0.png
#   inflating: aug_train_images/36041171f441_3.png
#   inflating: aug_train_images/b960142a8de7_4.png
#   inflating: aug_train_images/04ac765f91a1_0.png
#   inflating: aug_train_images/f55e1d2a19e4_2.png
#   inflating: aug_train_images/2209daf71aab.png
#   inflating: aug_train_images/5e7db41b3bee_4.png
#   inflating: aug_train_images/76c0c7e1b6cb.png
#   inflating: aug_train_images/9dab2e6ba44b.png
#   inflating: aug_train_images/8a9bef2fbd4e_0.png
#   inflating: aug_train_images/30941b65348b_3.png
#   inflating: aug_train_images/cbd0870aa933_4.png
#   inflating: aug_train_images/f5650eb52640.png
#   inflating: aug_train_images/6cd606dc52e9_0.png
#   inflating: aug_train_images/874f8c1929f6.png
#   inflating: aug_train_images/5d4e5fd34d91.png
#   inflating: aug_train_images/b55d2ddb3e75_2.png
#   inflating: aug_train_images/3b185ac445d0_0.png
#   inflating: aug_train_images/d16398c971e9_2.png
#   inflating: aug_train_images/5265dc9acdf8.png
#   inflating: aug_train_images/10f36b0239fb_0.png
#   inflating: aug_train_images/51aa3361294c.png
#   inflating: aug_train_images/b019a49787c1_6.png
#   inflating: aug_train_images/5712e2aa73a2_3.png
#   inflating: aug_train_images/3f0d3629d69e.png
#   inflating: aug_train_images/ef99c499d665.png
#   inflating: aug_train_images/ad2f0b9d059c_1.png
#   inflating: aug_train_images/8688f3d0fcaf_7.png
#   inflating: aug_train_images/f5e6226bd2e0_1.png
#   inflating: aug_train_images/913b1890ed1e.png
#   inflating: aug_train_images/1623e8e3adc4_5.png
#   inflating: aug_train_images/64678182d8a8_0.png
#   inflating: aug_train_images/7e5a76c4e103.png
#   inflating: aug_train_images/a4b8de38eac1_6.png
#   inflating: aug_train_images/6089fa333013_3.png
#   inflating: aug_train_images/8d4d14a4ab07.png
#   inflating: aug_train_images/a93f1ea3ff4a_0.png
#   inflating: aug_train_images/a87f53bc984a.png
#   inflating: aug_train_images/cc9270f06b65_0.png
#   inflating: aug_train_images/c568e5245ea5.png
#   inflating: aug_train_images/812d5adafaf2.png
#   inflating: aug_train_images/b99afe7137fb_3.png
#   inflating: aug_train_images/e76a9cbb2a8c_0.png
#   inflating: aug_train_images/052d9a3fe55a_0.png
#   inflating: aug_train_images/b64e1eef3d63.png
#   inflating: aug_train_images/2f42e20db938.png
#   inflating: aug_train_images/ae61e19fb766.png
#   inflating: aug_train_images/72595230840c_4.png
#   inflating: aug_train_images/de38adaae009.png
#   inflating: aug_train_images/cf603a9ef2d5.png
#   inflating: aug_train_images/247e98aba610_2.png
#   inflating: aug_train_images/8201cab8322d_2.png
#   inflating: aug_train_images/aa0afc41ed19.png
#   inflating: aug_train_images/248139c423c4.png
#   inflating: aug_train_images/8f2996b8d855_2.png
#   inflating: aug_train_images/a77eb914b383.png
#   inflating: aug_train_images/84b79243e430.png
#   inflating: aug_train_images/f0c13be90519.png
#   inflating: aug_train_images/6253f23229b1_2.png
#   inflating: aug_train_images/a1b12fdce6c3.png
#   inflating: aug_train_images/1c0cf251b426_0.png
#   inflating: aug_train_images/c9ea9d5eab65_6.png
#   inflating: aug_train_images/d7a01fca9838.png
#   inflating: aug_train_images/d6e26fe51dce_2.png
#   inflating: aug_train_images/31cb39681f6a_1.png
#   inflating: aug_train_images/f531232ecb55.png
#   inflating: aug_train_images/51030843fde2.png
#   inflating: aug_train_images/70f5caf5f305.png
#   inflating: aug_train_images/0981195eb9fb_0.png
#   inflating: aug_train_images/e1418d28d668.png
#   inflating: aug_train_images/0fb1053285cf.png
#   inflating: aug_train_images/9f1efb799b7b.png
#   inflating: aug_train_images/c7e827fc7f41_0.png
#   inflating: aug_train_images/f80118bbda18.png
#   inflating: aug_train_images/ce207b69ff37_7.png
#   inflating: aug_train_images/8b58f9a338e8.png
#   inflating: aug_train_images/62318d514160_1.png
#   inflating: aug_train_images/38055d8b9f08_5.png
#   inflating: aug_train_images/f2094a20b275_0.png
#   inflating: aug_train_images/e93394175a19.png
#   inflating: aug_train_images/be7bc89f5fec.png
#   inflating: aug_train_images/e32a359be36d_7.png
#   inflating: aug_train_images/188219f2d9c6.png
#   inflating: aug_train_images/65cf00be6fb4.png
#   inflating: aug_train_images/91cf56d3d1af_4.png
#   inflating: aug_train_images/45e4b7eada54_3.png
#   inflating: aug_train_images/43fb6eda9b97_0.png
#   inflating: aug_train_images/f1dc26c4bfa3_2.png
#   inflating: aug_train_images/26e231747848_0.png
#   inflating: aug_train_images/d1a24527a15d_4.png
#   inflating: aug_train_images/42cc993f23a9_5.png
#   inflating: aug_train_images/4a213b405ee4.png
#   inflating: aug_train_images/06024377d573.png
#   inflating: aug_train_images/6bcce181be65.png
#   inflating: aug_train_images/a4359815f152.png
#   inflating: aug_train_images/c62585bd68fb.png
#   inflating: aug_train_images/03c85870824c_2.png
#   inflating: aug_train_images/2fde69f20585_0.png
#   inflating: aug_train_images/29a13e666266.png
#   inflating: aug_train_images/2221cf5c7935.png
#   inflating: aug_train_images/28f73575e1f2.png
#   inflating: aug_train_images/df6d13d04da1.png
#   inflating: aug_train_images/b95d4dd8e5e2.png
#   inflating: aug_train_images/9b093fe95d6b_7.png
#   inflating: aug_train_images/cbc2e57447c2_0.png
#   inflating: aug_train_images/3f752fcccec0_1.png
#   inflating: aug_train_images/a80dab8eddf4_0.png
#   inflating: aug_train_images/4fecf87184e6_4.png
#   inflating: aug_train_images/9b418ce42c13.png
#   inflating: aug_train_images/501c319f7a9f.png
#   inflating: aug_train_images/0684311afdfc_3.png
#   inflating: aug_train_images/ca6842bfcbc9_1.png
#   inflating: aug_train_images/a11bf2edd470_3.png
#   inflating: aug_train_images/22098b1fe461_2.png
#   inflating: aug_train_images/6ba5ed791444_0.png
#   inflating: aug_train_images/1411c8ab7161_0.png
#   inflating: aug_train_images/aa5ce75edcf5.png
#   inflating: aug_train_images/306c841af3fc.png
#   inflating: aug_train_images/22ce8ef69357_0.png
#   inflating: aug_train_images/0a3202889f4d_1.png
#   inflating: aug_train_images/9bf060db8376_6.png
#   inflating: aug_train_images/4c6c5a1bf5ab.png
#   inflating: aug_train_images/bb783d8e496f_1.png
#   inflating: aug_train_images/12a82fc7d73e_0.png
#   inflating: aug_train_images/405b4f78658f_7.png
#   inflating: aug_train_images/dc0f6e5b489b.png
#   inflating: aug_train_images/f901d460517c_1.png
#   inflating: aug_train_images/e4210e7fe587.png
#   inflating: aug_train_images/8c7c26c52a6c.png
#   inflating: aug_train_images/e12d41e7b221_0.png
#   inflating: aug_train_images/493d99f030e2.png
#   inflating: aug_train_images/28503940d10b.png
#   inflating: aug_train_images/4f5dd7660b17.png
#   inflating: aug_train_images/79059d0592c4.png
#   inflating: aug_train_images/d67374d3fa2a_0.png
#   inflating: aug_train_images/069f43616fab_1.png
#   inflating: aug_train_images/6dfd80748e72_0.png
#   inflating: aug_train_images/fcc55ae641ae_0.png
#   inflating: aug_train_images/65e120143825_4.png
#   inflating: aug_train_images/b70cb31b9abb_2.png
#   inflating: aug_train_images/b9c7c5182075.png
#   inflating: aug_train_images/599b89048034_0.png
#   inflating: aug_train_images/1177d583c807.png
#   inflating: aug_train_images/ae57c8630249.png
#   inflating: aug_train_images/b3d135bd3bb5_0.png
#   inflating: aug_train_images/91e2c2890c9f_0.png
#   inflating: aug_train_images/c013e869acce.png
#   inflating: aug_train_images/4f0866b90c27_2.png
#   inflating: aug_train_images/b56340f472d2_1.png
#   inflating: aug_train_images/d3e884109b45_6.png
#   inflating: aug_train_images/d25b8a8ad3c4.png
#   inflating: aug_train_images/070f67572d03_1.png
#   inflating: aug_train_images/e2a233493b90_3.png
#   inflating: aug_train_images/3fa4f4d77177_4.png
#   inflating: aug_train_images/5d6239c0fd39.png
#   inflating: aug_train_images/8be6629a6039.png
#   inflating: aug_train_images/fd0a70082e7c.png
#   inflating: aug_train_images/9a94e0316ee3_6.png
#   inflating: aug_train_images/21abd36095a1_1.png
# Archive:  resnet50.zip
#   inflating: kaggle-data/resnet50/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
#   inflating: kaggle-data/resnet50/resnet50_weights_tf_dim_ordering_tf_kernels.h5
#   inflating: kaggle-data/resnet50/imagenet_class_index.json

# %%
WORKERS = 2
CHANNEL = 3

import warnings
warnings.filterwarnings("ignore")
SIZE = 300
NUM_CLASSES = 5

# %%
df_train = pd.read_csv('kaggle-data/aug_train.csv')
df_test = pd.read_csv('kaggle-data/test.csv')

df_train.columns = ['id_code', 'diagnosis']

x = df_train['id_code']
y = df_train['diagnosis']

# x, y = shuffle(x, y, random_state=8)
y.hist()

# %%
def get_label(diagnosis):
  return [i for i in range(diagnosis + 1)]
#     return ','.join([str(i+1) for i in range(diagnosis + 1)])
df_train['label'] = df_train.diagnosis.apply(get_label)
df_train.head()
# Out:
#           id_code  diagnosis            label
# 0  000c1434d8d7_0          2        [0, 1, 2]
# 1    001639a390f0          4  [0, 1, 2, 3, 4]
# 2  001639a390f0_0          4  [0, 1, 2, 3, 4]
# 3  001639a390f0_1          4  [0, 1, 2, 3, 4]
# 4  001639a390f0_2          4  [0, 1, 2, 3, 4]

# %%
mlb = MultiLabelBinarizer(classes=[0,1,2,3,4])
# labels = [(1,2), (1,), (1,2)]

# y = mlb.fit_transform(y)
# mlb.fit_transform(labels)
# mlb.fit_transform(list(y[i]) for i in range(0,len(y)))
# yy = mlb.fit_transform(df_train['diagnosis'])
# mlb.classes_

# %%
y = df_train['label']
y = mlb.fit_transform(y)
# y = to_categorical(y, num_classes=NUM_CLASSES)
train_x, valid_x, train_y, valid_y = train_test_split(x, y, test_size=0.15,
                                                      stratify=y, random_state=8)
print(train_x.shape)
print(train_y.shape)
print(valid_x.shape)
print(valid_y.shape)
# Out:
# (7785,)
# (7785, 5)
# (1374,)
# (1374, 5)

# %%
sometimes = lambda aug: iaa.Sometimes(0.5, aug)
seq = iaa.Sequential([
    sometimes(
        iaa.OneOf([
            iaa.Add((-10, 10), per_channel=0.5),
            iaa.Multiply((0.9, 1.1), per_channel=0.5),
            iaa.ContrastNormalization((0.9, 1.1), per_channel=0.5)
        ])
    ),
    iaa.Fliplr(0.5),
    iaa.Crop(percent=(0, 0.1)),
    # iaa.Flipud(0.5)
],random_order=True)

# %%
class My_Generator(Sequence):

    def __init__(self, image_filenames, labels,
                 batch_size, is_train=True,
                 mix=False, augment=False):
        self.image_filenames, self.labels = image_filenames, labels
        self.batch_size = batch_size
        self.is_train = is_train
        self.is_augment = augment
        if(self.is_train):
            self.on_epoch_end()
        self.is_mix = mix

    def __len__(self):
        return int(np.ceil(len(self.image_filenames) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.image_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.labels[idx * self.batch_size:(idx + 1) * self.batch_size]

        if(self.is_train):
            return self.train_generate(batch_x, batch_y)
        return self.valid_generate(batch_x, batch_y)

    def on_epoch_end(self):
        if(self.is_train):
            self.image_filenames, self.labels = shuffle(self.image_filenames, self.labels)
        else:
            pass
    
    def mix_up(self, x, y):
        lam = np.random.beta(0.2, 0.4)
        ori_index = np.arange(int(len(x)))
        index_array = np.arange(int(len(x)))
        np.random.shuffle(index_array)        
        
        mixed_x = lam * x[ori_index] + (1 - lam) * x[index_array]
        mixed_y = lam * y[ori_index] + (1 - lam) * y[index_array]
        
        return mixed_x, mixed_y

    def train_generate(self, batch_x, batch_y):
        batch_images = []
        for (sample, label) in zip(batch_x, batch_y):
            img = cv2.imread('kaggle-data/aug_train_images/'+sample+'.png')
            img = cv2.resize(img, (SIZE, SIZE))
            if(self.is_augment):
                img = seq.augment_image(img)
            batch_images.append(img)
        batch_images = np.array(batch_images, np.float32) / 255
        batch_y = np.array(batch_y, np.float32)
        if(self.is_mix):
            batch_images, batch_y = self.mix_up(batch_images, batch_y)
#         print('batch_images shape: {} batch_y shape:{}'.format(batch_images.shape, batch_y.shape))
        return batch_images, batch_y

    def valid_generate(self, batch_x, batch_y):
        batch_images = []
        for (sample, label) in zip(batch_x, batch_y):
            img = cv2.imread('kaggle-data/aug_train_images/'+sample+'.png')
            img = cv2.resize(img, (SIZE, SIZE))
            batch_images.append(img)
        batch_images = np.array(batch_images, np.float32) / 255
        batch_y = np.array(batch_y, np.float32)
        return batch_images, batch_y

# %%
def create_model(input_shape, n_out, model_weights):
    input_tensor = Input(shape=input_shape)
    base_model = ResNet50(include_top=False,
                   weights=None,
                   input_tensor=input_tensor)
    base_model.load_weights('kaggle-data/resnet50/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5')
#     x = GlobalAveragePooling2D()(base_model.output)
    
    classifier = Sequential()
    classifier.add(GlobalAveragePooling2D())
#     classifier.add(Flatten())   
    classifier.add(Dropout(0.5))
    
    classifier.add(Dense(1024))
    classifier.add(BatchNormalization())
    classifier.add(Activation('relu'))
    classifier.add(Dropout(0.5))
    
    classifier.add(Dense(n_out, activation='sigmoid', name='final_output'))
    #Use sigmoid for multilabel and softmax for single label classification
#     final_output = Dense(n_out, activation='sigmoid', name='final_output')(classifier.output)
    
    model = Sequential([
    base_model, 
    classifier
])
#     model = Model(input_tensor, final_output)
#     model.load_weights(model_weights)
    
    return model

# %% [markdown]
# ## LRFinder

# %%
from keras.callbacks import LambdaCallback

class LRFinder:
    """
    Plots the change of the loss function of a Keras model when the learning rate is exponentially increasing.
    See for details:
    https://towardsdatascience.com/estimating-optimal-learning-rate-for-a-deep-neural-network-ce32f2556ce0
    """
    def __init__(self, model):
        self.model = model
        self.losses = []
        self.lrs = []
        self.best_loss = 1e9

    def on_batch_end(self, batch, logs):
        # Log the learning rate
        lr = K.get_value(self.model.optimizer.lr)
        self.lrs.append(lr)

        # Log the loss
        loss = logs['loss']
        self.losses.append(loss)

        # Check whether the loss got too large or NaN
        if math.isnan(loss) or loss > self.best_loss * 4:
            self.model.stop_training = True
            return

        if loss < self.best_loss:
            self.best_loss = loss

        # Increase the learning rate for the next batch
        lr *= self.lr_mult
        K.set_value(self.model.optimizer.lr, lr)
        print("Current Learning Rate{}".format(lr))

    def find(self, train_gen, start_lr, end_lr, batch_size=64, epochs=1, steps=1):
        num_batches = epochs * steps
#         x_train.shape[0] / batch_size
        self.lr_mult = (end_lr / start_lr) ** (1 / num_batches)

        # Save weights into a file
        self.model.save_weights('tmp.h5')

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch, logs: self.on_batch_end(batch, logs))

#         self.model.fit(x_train, y_train,
#                         batch_size=batch_size, epochs=epochs,
#                         callbacks=[callback])
        self.model.fit_generator(
                  train_gen,
                  steps_per_epoch=steps,
                  
                  epochs=epochs,
                  verbose=1,
                  workers=1, use_multiprocessing=False,
                  callbacks=[callback])

        # Restore the weights to the state before model fitting
        self.model.load_weights('tmp.h5')

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def plot_loss(self, n_skip_beginning=10, n_skip_end=5):
        """
        Plots the loss.
        Parameters:
            n_skip_beginning - number of batches to skip on the left.
            n_skip_end - number of batches to skip on the right.
        """
        plt.ylabel("loss")
        plt.xlabel("learning rate (log scale)")
        plt.plot(self.lrs[n_skip_beginning:-n_skip_end], self.losses[n_skip_beginning:-n_skip_end])
        plt.xscale('log')

    def plot_loss_change(self, sma=1, n_skip_beginning=10, n_skip_end=5, y_lim=(-0.01, 0.01)):
        """
        Plots rate of change of the loss function.
        Parameters:
            sma - number of batches for simple moving average to smooth out the curve.
            n_skip_beginning - number of batches to skip on the left.
            n_skip_end - number of batches to skip on the right.
            y_lim - limits for the y axis.
        """
        assert sma >= 1
        derivatives = [0] * sma
        for i in range(sma, len(self.lrs)):
            derivative = (self.losses[i] - self.losses[i - sma]) / sma
            derivatives.append(derivative)

        plt.ylabel("rate of loss change")
        plt.xlabel("learning rate (log scale)")
        plt.plot(self.lrs[n_skip_beginning:-n_skip_end], derivatives[n_skip_beginning:-n_skip_end])
        plt.xscale('log')
        plt.ylim(y_lim)

# %%
run_opts = tf.RunOptions(report_tensor_allocations_upon_oom = True)
model = create_model(
    input_shape=(SIZE,SIZE,3), 
    n_out=NUM_CLASSES,
    model_weights='kaggle-data/resnet50/Resnet50_bestqwk.h5')
model.compile(loss='binary_crossentropy',
                  optimizer=Adam(),
                  metrics=['accuracy'], options = run_opts)
lr_finder = LRFinder(model)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0814 09:09:34.177174 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0814 09:09:34.194610 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0814 09:09:34.201596 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0814 09:09:34.234092 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0814 09:09:34.235145 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0814 09:09:36.346253 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0814 09:09:36.430413 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0814 09:09:50.611902 140233567254400 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0814 09:09:50.949522 140233567254400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0814 09:09:50.962381 140233567254400 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
def determineLearningRate():    
    batch_size = 64
    num_classes = NUM_CLASSES
    epochs = 5
    
    train_generator = My_Generator(train_x, train_y, batch_size, is_train=True)
    steps = np.ceil(float(len(train_x)) / float(batch_size))
    print(steps)
    lr_finder.find(train_generator, start_lr=0.00001, end_lr=0.1, batch_size=batch_size, epochs=5, steps=steps)
    lr_finder.plot_loss(n_skip_beginning=20, n_skip_end=5)
    plt.show()
    return model

# %%
determineLearningRate()
# Out:
# 122.0
# Epoch 1/5

# %%
# !kill -9 -1

# %%
# !mkdir 'kaggle-data/model'
# Out:
# mkdir: cannot create directory ‘kaggle-data/model’: File exists

# %%
# create callbacks list
from keras.callbacks import (ModelCheckpoint, LearningRateScheduler,
                             EarlyStopping, ReduceLROnPlateau,CSVLogger)

epochs = 15; batch_size = 16
checkpoint = ModelCheckpoint('kaggle-data/model/Resnet50-{epoch:02d}-{val_acc:.4f}.h5', monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)
# checkpoint = ModelCheckpoint('kaggle-data/model/xception-model.h5', verbose=1, monitor='val_acc',
#                               save_best_only=True, save_weights_only = True)
reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, 
                                   verbose=1, mode='auto', epsilon=0.0001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=9)

csv_logger = CSVLogger(filename='kaggle-data/model/training_log.csv',
                       separator=',',
                       append=True)
# callbacks_list = [checkpoint, csv_logger, reduceLROnPlat, early]

train_generator = My_Generator(train_x, train_y, 128, is_train=True)
train_mixup = My_Generator(train_x, train_y, batch_size, is_train=True, mix=True, augment=True)
valid_generator = My_Generator(valid_x, valid_y, batch_size, is_train=False)

model = create_model(
    input_shape=(SIZE,SIZE,3), 
    n_out=NUM_CLASSES,
    model_weights='kaggle-data/resnet50/Resnet50_bestqwk.h5')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0814 08:36:07.700215 140155323684736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0814 08:36:07.715320 140155323684736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0814 08:36:07.722645 140155323684736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0814 08:36:07.754548 140155323684736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0814 08:36:07.755895 140155323684736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0814 08:36:08.368358 140155323684736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0814 08:36:08.461435 140155323684736 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0814 08:36:22.627359 140155323684736 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# reference link: https://www.kaggle.com/christofhenkel/weighted-kappa-loss-for-keras-tensorflow
def kappa_loss(y_true, y_pred, y_pow=2, eps=1e-12, N=5, bsize=32, name='kappa'):
    """A continuous differentiable approximation of discrete kappa loss.
        Args:
            y_pred: 2D tensor or array, [batch_size, num_classes]
            y_true: 2D tensor or array,[batch_size, num_classes]
            y_pow: int,  e.g. y_pow=2
            N: typically num_classes of the model
            bsize: batch_size of the training or validation ops
            eps: a float, prevents divide by zero
            name: Optional scope/name for op_scope.
        Returns:
            A tensor with the kappa loss."""

    with tf.name_scope(name):
        y_true = tf.to_float(y_true)
        repeat_op = tf.to_float(tf.tile(tf.reshape(tf.range(0, N), [N, 1]), [1, N]))
        repeat_op_sq = tf.square((repeat_op - tf.transpose(repeat_op)))
        weights = repeat_op_sq / tf.to_float((N - 1) ** 2)
    
        pred_ = y_pred ** y_pow
        try:
            pred_norm = pred_ / (eps + tf.reshape(tf.reduce_sum(pred_, 1), [-1, 1]))
        except Exception:
            pred_norm = pred_ / (eps + tf.reshape(tf.reduce_sum(pred_, 1), [bsize, 1]))
    
        hist_rater_a = tf.reduce_sum(pred_norm, 0)
        hist_rater_b = tf.reduce_sum(y_true, 0)
    
        conf_mat = tf.matmul(tf.transpose(pred_norm), y_true)
    
        nom = tf.reduce_sum(weights * conf_mat)
        denom = tf.reduce_sum(weights * tf.matmul(
            tf.reshape(hist_rater_a, [N, 1]), tf.reshape(hist_rater_b, [1, N])) /
                              tf.to_float(bsize))
    
        return nom*0.5 / (denom + eps) + categorical_crossentropy(y_true, y_pred)*0.5

# %%
from keras.callbacks import Callback
class QWKEvaluation(Callback):
    def __init__(self, validation_data=(), batch_size=64, interval=1):
        super(Callback, self).__init__()

        self.interval = interval
        self.batch_size = batch_size
        self.valid_generator, self.y_val = validation_data
        self.history = []

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict_generator(generator=self.valid_generator,
                                                  steps=np.ceil(float(len(self.y_val)) / float(self.batch_size)),
                                                  workers=1, use_multiprocessing=False,
                                                  verbose=1)
            
            def get_pred(y):
#                 print(y[0])
                y_pred = y > 0.5
#                 print(y_pred[0])
                y_pred = y_pred.astype(int).sum(axis=1) - 1
#                 print(y_pred.reshape(-1))
                return y_pred.reshape(-1)
                
            def flatten(y):
                return np.argmax(y, axis=1).reshape(-1)
            
            score = cohen_kappa_score(get_pred(self.y_val),
                                      get_pred(y_pred),
                                      labels=[0,1,2,3,4],
                                      weights='quadratic')
            print("\n epoch: %d - QWK_score: %.6f \n" % (epoch+1, score))
            self.history.append(score)
            if score >= max(self.history):
                print('saving checkpoint: ', score)
                self.model.save('kaggle-data/model/Resnet50_qwk-{0:02d}-{1:.4f}.h5'.format(epoch, score))

qwk = QWKEvaluation(validation_data=(valid_generator, valid_y),
                    batch_size=batch_size, interval=1)

# %%
train_y.shape
# Out:
# (7785, 5)

# %%
import gc
gc.collect()
K.clear_session()

# %%
# train all layers
for layer in model.layers:
    layer.trainable = True

callbacks_list = [checkpoint, csv_logger, reduceLROnPlat, early, qwk]
model.compile(
    loss='binary_crossentropy',
    #loss='categorical_crossentropy',
#              loss=kappa_loss,
            optimizer=Adam(lr=1e-3),
            metrics=['accuracy'])
#, metrics=['accuracy']
history = model.fit_generator(
    train_mixup,
    steps_per_epoch=np.ceil(float(len(train_x)) / float(batch_size)),
    validation_data=valid_generator,
    validation_steps=np.ceil(float(len(valid_x)) / float(batch_size)),
    epochs=epochs,
    verbose=1,
    workers=1, use_multiprocessing=False,
    callbacks=callbacks_list)
# Out:
# W0813 09:07:49.613246 139693550929792 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0813 09:07:49.627180 139693550929792 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/15
# 487/487 [==============================] - 467s 960ms/step - loss: 0.3667 - acc: 0.6416 - val_loss: 1.2505 - val_acc: 0.7342
#
# Epoch 00001: val_loss improved from inf to 1.25047, saving model to kaggle-data/model/Resnet50-01-0.7342.h5
# 86/86 [==============================] - 25s 287ms/step
#
#  epoch: 1 - QWK_score: 0.048708
#
# saving checkpoint:  0.048708314790361196
# Epoch 2/15
# 487/487 [==============================] - 446s 917ms/step - loss: 0.3167 - acc: 0.6502 - val_loss: 0.4712 - val_acc: 0.7988
#
# Epoch 00002: val_loss improved from 1.25047 to 0.47118, saving model to kaggle-data/model/Resnet50-02-0.7988.h5
# 86/86 [==============================] - 23s 269ms/step
#
#  epoch: 2 - QWK_score: 0.466772
#
# saving checkpoint:  0.46677189836390853
# Epoch 3/15
# 487/487 [==============================] - 446s 916ms/step - loss: 0.2990 - acc: 0.6571 - val_loss: 0.5031 - val_acc: 0.8151
#
# Epoch 00003: val_loss did not improve from 0.47118
# 86/86 [==============================] - 23s 269ms/step
#
#  epoch: 3 - QWK_score: 0.452464
#
# Epoch 4/15
# 487/487 [==============================] - 449s 923ms/step - loss: 0.2904 - acc: 0.6598 - val_loss: 0.2566 - val_acc: 0.8885
#
# Epoch 00004: val_loss improved from 0.47118 to 0.25663, saving model to kaggle-data/model/Resnet50-04-0.8885.h5
# 86/86 [==============================] - 23s 271ms/step
#
#  epoch: 4 - QWK_score: 0.809590
#
# saving checkpoint:  0.80959032924405
# Epoch 5/15
# 487/487 [==============================] - 450s 925ms/step - loss: 0.2912 - acc: 0.6565 - val_loss: 0.2499 - val_acc: 0.8911
#
# Epoch 00005: val_loss improved from 0.25663 to 0.24992, saving model to kaggle-data/model/Resnet50-05-0.8911.h5
# 86/86 [==============================] - 23s 271ms/step
#
#  epoch: 5 - QWK_score: 0.775962
#
# Epoch 6/15
# 487/487 [==============================] - 451s 926ms/step - loss: 0.2824 - acc: 0.6637 - val_loss: 1.2328 - val_acc: 0.6584
#
# Epoch 00006: val_loss did not improve from 0.24992
# 86/86 [==============================] - 23s 271ms/step
#
#  epoch: 6 - QWK_score: 0.152860
#
# Epoch 7/15
# 487/487 [==============================] - 451s 925ms/step - loss: 0.2788 - acc: 0.6606 - val_loss: 0.3012 - val_acc: 0.8729
#
# Epoch 00007: val_loss did not improve from 0.24992
# 86/86 [==============================] - 23s 271ms/step
#
#  epoch: 7 - QWK_score: 0.682874
#
# Epoch 8/15
# 487/487 [==============================] - 450s 925ms/step - loss: 0.2723 - acc: 0.6654 - val_loss: 0.2189 - val_acc: 0.9057
#
# Epoch 00008: val_loss improved from 0.24992 to 0.21893, saving model to kaggle-data/model/Resnet50-08-0.9057.h5
# 86/86 [==============================] - 23s 271ms/step
#
#  epoch: 8 - QWK_score: 0.804764
#
# Epoch 9/15
# 487/487 [==============================] - 449s 923ms/step - loss: 0.2623 - acc: 0.6653 - val_loss: 0.3052 - val_acc: 0.8640
#
# Epoch 00009: val_loss did not improve from 0.21893
# 86/86 [==============================] - 23s 269ms/step
#
#  epoch: 9 - QWK_score: 0.709303
#
# Epoch 10/15
# 487/487 [==============================] - 448s 919ms/step - loss: 0.2616 - acc: 0.6652 - val_loss: 0.2118 - val_acc: 0.9116
#
# Epoch 00010: val_loss improved from 0.21893 to 0.21176, saving model to kaggle-data/model/Resnet50-10-0.9116.h5
# 86/86 [==============================] - 23s 270ms/step
#
#  epoch: 10 - QWK_score: 0.810833
#
# saving checkpoint:  0.8108328817654928
# Epoch 11/15
# 487/487 [==============================] - 447s 919ms/step - loss: 0.2565 - acc: 0.6647 - val_loss: 0.1950 - val_acc: 0.9195
#
# Epoch 00011: val_loss improved from 0.21176 to 0.19497, saving model to kaggle-data/model/Resnet50-11-0.9195.h5
# 86/86 [==============================] - 23s 269ms/step
#
#  epoch: 11 - QWK_score: 0.861617
#
# saving checkpoint:  0.8616173096797817
# Epoch 12/15
# 487/487 [==============================] - 447s 917ms/step - loss: 0.2496 - acc: 0.6704 - val_loss: 0.2287 - val_acc: 0.9032
#
# Epoch 00012: val_loss did not improve from 0.19497
# 86/86 [==============================] - 23s 269ms/step
#
#  epoch: 12 - QWK_score: 0.787961
#
# Epoch 13/15
# 487/487 [==============================] - 447s 917ms/step - loss: 0.2571 - acc: 0.6703 - val_loss: 0.1790 - val_acc: 0.9294
#
# Epoch 00013: val_loss improved from 0.19497 to 0.17902, saving model to kaggle-data/model/Resnet50-13-0.9294.h5
# 86/86 [==============================] - 23s 269ms/step
#
#  epoch: 13 - QWK_score: 0.879448
#
# saving checkpoint:  0.879447695118444
# Epoch 14/15
# 487/487 [==============================] - 447s 917ms/step - loss: 0.2502 - acc: 0.6698 - val_loss: 0.1960 - val_acc: 0.9204
#
# Epoch 00014: val_loss did not improve from 0.17902
# 86/86 [==============================] - 23s 269ms/step
#
#  epoch: 14 - QWK_score: 0.839317
#
# Epoch 15/15
# 487/487 [==============================] - 447s 917ms/step - loss: 0.2434 - acc: 0.6725 - val_loss: 0.2042 - val_acc: 0.9146
#
# Epoch 00015: val_loss did not improve from 0.17902
# 86/86 [==============================] - 23s 270ms/step
#
#  epoch: 15 - QWK_score: 0.826314

# %%
# epochs = 30
# history2 = model.fit_generator(
#     train_mixup,
#     steps_per_epoch=np.ceil(float(len(train_x)) / float(batch_size)),
#     validation_data=valid_generator,
#     validation_steps=np.ceil(float(len(valid_x)) / float(batch_size)),
#     epochs=epochs,
#     initial_epoch=15,
#     verbose=1,
#     workers=1, use_multiprocessing=False,
#     callbacks=callbacks_list)

# %% [markdown]
# Load the best model

# %%
model.load_

# %% [markdown]
# # Evaluate Model

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
all_scores = []
for i, name in tqdm(enumerate(valid_x)):
  path = os.path.join('kaggle-data/aug_train_images/', name+'.png')
  image = cv2.imread(path)
  image = cv2.resize(image, (SIZE, SIZE))

  scores = model.evaluate((image[np.newaxis])/255, np.reshape(valid_y[i], (1,5)), verbose=0)
  all_scores.append(scores)

mean = np.mean(all_scores, axis=0)
sd = np.std(all_scores, axis=0)
print("Loss:    %.2f%% (+/- %.2f%%)" % (mean[0], sd[0]))
print("Accuracy:%.2f%% (+/- %.2f%%)" % (mean[1], sd[1]))
# Out:
# 1374it [01:07, 20.22it/s]
# Loss:    3.80% (+/- 3.01%)
# Accuracy:1.00% (+/- 0.00%)

# %%
history.history

# %%
def get_pred(y):
  y_pred = y > 0.5
  y_pred = y_pred.astype(int).sum(axis=1) - 1
  return y_pred.reshape(-1)

def check_model(hist, model):
  
  #Plot the curves
  N = len(hist.history['loss'])

  plt.style.use("ggplot")
  plt.figure()
  plt.plot(np.arange(0, N), hist.history["loss"], label="train_loss")
  plt.plot(np.arange(0, N), hist.history["val_loss"], label="val_loss")
  
 
  plt.title("Training Loss on Dataset")
  plt.xlabel("Epoch #")
  plt.ylabel("Loss")
  plt.legend(loc="lower left")
  
  plt.figure()
  plt.plot(np.arange(0, N), hist.history["acc"], label="train_acc")
  plt.plot(np.arange(0, N), hist.history["val_acc"], label="val_acc")
  plt.title("Training Accuracy on Dataset")
  plt.xlabel("Epoch #")
  plt.ylabel("Accuracy")
  plt.legend(loc="lower left")
  
  plt.figure()
  plt.plot(np.arange(0, N), qwk.history, label="kappa_score")
  plt.title("Kappa score on Dataset")
  plt.xlabel("Epoch #")
  plt.ylabel("kappa")
  plt.legend(loc="lower left")
  
  plt.style.use("ggplot")
  plt.figure()
  plt.plot(np.arange(0, N), hist.history["lr"], label="learning_rate")
 
  plt.title("Learning Rate on Dataset")
  plt.xlabel("Epoch #")
  plt.ylabel("LR")
  plt.legend(loc="lower left")
  
  
  #confusion matrix
  preds = []
  for i, name in tqdm(enumerate(valid_x)):
      path = os.path.join('kaggle-data/aug_train_images/', name+'.png')
      image = cv2.imread(path)
  #     print(str(path))
      image = cv2.resize(image, (SIZE, SIZE))
      score_predict = model.predict((image[np.newaxis])/255)
      label_predict = get_pred(score_predict)
#       print('Predict {}-->{}'.format(score_predict, label_predict))
#       label_predict = np.argmax(score_predict)
      
      preds.append(label_predict)

#   valid_labels = np.argmax(valid_y, axis=-1)
  valid_labels = get_pred(valid_y)
  
  cm  = confusion_matrix(valid_labels, preds)
  plt.figure()
  plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues, show_normed=True, show_absolute=False)
  plt.show()

# %%
check_model(history, model)
# Out:
# 1374it [00:56, 24.29it/s]

# %%
  def get_pred(y):
    y_pred = y > 0.5
    mask = y_pred == 0
    return np.clip(np.where(mask.any(1), mask.argmax(1), 5) - 1, 0, 4)

  preds = []
  for i, name in tqdm(enumerate(valid_x)):
      path = os.path.join('kaggle-data/aug_train_images/', name+'.png')
      image = cv2.imread(path)
  #     print(str(path))
      image = cv2.resize(image, (SIZE, SIZE))
      score_predict = model.predict((image[np.newaxis])/255)
      label_predict = get_pred(score_predict)
#       print('Predict {}-->{}'.format(score_predict, label_predict))
#       label_predict = np.argmax(score_predict)
      
      preds.append(label_predict)

#   valid_labels = np.argmax(valid_y, axis=-1)
  valid_labels = get_pred(valid_y)
  
  cm  = confusion_matrix(valid_labels, preds)
  plt.figure()
  plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues, show_normed=True, show_absolute=False)
  plt.show()

# %%
qwk.history

# %%
check_model(history, model)

# %%
check_model(history2, model)

# %% [markdown]
# # Save Model

# %%
# %cd kaggle-data/model
# Out:
# /content/kaggle-data/model

# %%
# !zip resnet50_multiL5_nobn.zip Resnet50_qwk-12-0.8794.h5 Resnet50_qwk-10-0.8616.h5
# !cp resnet50_multiL5_nobn.zip /content/gdrive/My\ Drive/Colab\ Notebooks/
# Out:
#   adding: Resnet50_qwk-12-0.8794.h5 (deflated 12%)
#   adding: Resnet50_qwk-10-0.8616.h5 (deflated 12%)

# %%
# !zip resnet50_aug2.zip Resnet50_bestqwk-0016-0.95.h5
# !cp resnet50_aug2.zip /content/gdrive/My\ Drive/Colab\ Notebooks/
# Out:
#   adding: Resnet50_bestqwk-0016-0.95.h5 (deflated 9%)

# %%
# %cd ../../
# Out:
# /content

# %% [markdown]
# # Compare models

# %%
# !cp /content/gdrive/My\ Drive/Colab\ Notebooks/resnet50_aug3.zip .
# !mkdir resnet50_aug3
# !unzip resnet50_aug3.zip -d resnet50_aug3
# Out:
# Archive:  resnet50_aug3.zip
#   inflating: resnet50_aug3/Resnet50-09-0.8952.h5
#   inflating: resnet50_aug3/Resnet50_qwk-23-0.9533.h5

# %%
# !cp /content/gdrive/My\ Drive/Colab\ Notebooks/resnet50_aug4.zip .
# !mkdir resnet50_aug4
# !unzip resnet50_aug4.zip -d resnet50_aug4
# Out:
# Archive:  resnet50_aug4.zip
#   inflating: resnet50_aug4/Resnet50_qwk-29-0.9558.h5

# %%
def preprocess_image(img):
  
  if img.shape[2] ==1:
    img = np.dstack([img, img, img])

  img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  ret, img2 = cv2.threshold(img1, 10, 255, cv2.THRESH_BINARY)
  points = np.argwhere(img2!=0)
  points = np.fliplr(points)
  x, y, w, h = cv2.boundingRect(points)

  color_cropped = img[y:y+h, x:x+w]

  clahe = cv2.createCLAHE(clipLimit=4.0)

  lab = cv2.cvtColor(color_cropped, cv2.COLOR_BGR2LAB)
  lab_planes = cv2.split(lab)
  lab_planes[0] = clahe.apply(lab_planes[0])
  lab_planes[1] = clahe.apply(lab_planes[1])
  lab_planes[2] = clahe.apply(lab_planes[2])
  
  out = cv2.merge(lab_planes)
  img3 = cv2.cvtColor(out, cv2.COLOR_LAB2BGR)
  
  img = cv2.resize(img3, (SIZE,SIZE), cv2.INTER_AREA)
  
#   img = img.astype(np.float32)/255
  
  return img

# %%
train, val = train_test_split(df_train, test_size=0.4)
train_data = train

# %%
train.head()
# Out:
#              id_code  diagnosis
# 7906    d9e58e4d8689          0
# 5884    a2ddabee14e9          4
# 191   05a5183c92d0_0          1
# 7120  c3cd0200df79_1          3
# 7202    c613db1cab27          2

# %%
model1 = create_model(
    input_shape=(SIZE,SIZE,3), 
    n_out=NUM_CLASSES,
    model_weights="resnet50_aug3/Resnet50-09-0.8952.h5")
model1.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=Adam(1e-3))

model2 = create_model(
    input_shape=(SIZE,SIZE,3), 
    n_out=NUM_CLASSES,
    model_weights='resnet50_aug4/Resnet50_qwk-29-0.9558.h5')
model2.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer=Adam(1e-3))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0807 06:26:48.074534 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0807 06:26:48.142511 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0807 06:26:48.170713 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0807 06:26:48.221229 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0807 06:26:48.222414 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0807 06:26:51.342936 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0807 06:26:51.435522 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0807 06:26:57.459065 139889221781376 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0807 06:27:00.936355 139889221781376 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#Evaluate with train data itself
train_img = []
train_labels = []

for idx, row in train_data.iterrows():
    path = 'kaggle-data/aug_train_images/' + row['id_code']+'.png'
    img = cv2.imread(path)
    img = preprocess_image(img)

    label = to_categorical(int(row['diagnosis']), num_classes=5)
    train_img.append(img)
    train_labels.append(label)
    
train_img = np.array(train_img)
train_labels = np.array(train_labels)

# %% [markdown]
# ## Evaluate First Model

# %%
eval_loss1, eval_score1 = model1.evaluate(train_img, train_labels, batch_size=16)
print("Loss on test set: ", eval_loss1)
print("Accuracy on test set: ", eval_score1)
# Out:
# 5495/5495 [==============================] - 96s 18ms/step
# Loss on test set:  7.650551852624561
# Accuracy on test set:  0.2043676069316482

# %%
#Evaluate with train data itself
predicted1 = []
# train_labels = []

for idx, row in train_data.iterrows():
    path = 'kaggle-data/aug_train_images/' + row['id_code']+'.png'
    img = cv2.imread(path)
    img = preprocess_image(img)

    label = to_categorical(int(row['diagnosis']), num_classes=5)
    score_predict = model1.predict((img[np.newaxis])/255)
    label_predict = np.argmax(score_predict)
    predicted1.append(str(label_predict))

# %%
cm  = confusion_matrix(orig_train_labels, predicted1)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues, show_normed=True, show_absolute=False)
#plt.xticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
#plt.yticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f298a386d8e8> in <module>()
# ----> 1 cm  = confusion_matrix(orig_train_labels, predicted1)
#       2 plt.figure()
#       3 plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues, show_normed=True, show_absolute=False)
#       4 #plt.xticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
#       5 #plt.yticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     256
#     257     if labels is None:
# --> 258         labels = unique_labels(y_true, y_pred)
#     259     else:
#     260         labels = np.asarray(labels)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#      98     # Check that we don't mix string type with number type
#      99     if (len(set(isinstance(label, str) for label in ys_labels)) > 1):
# --> 100         raise ValueError("Mix of label input types (string and number)")
#     101
#     102     return np.array(sorted(ys_labels))
#
# ValueError: Mix of label input types (string and number)

# %%
preds1 = model1.predict(train_img, batch_size=16)
preds1 = np.argmax(preds1, axis=-1)

# Original labels
orig_train_labels = np.argmax(train_labels, axis=-1)

# %% [markdown]
# ## Confusion Matrix

# %%
cm  = confusion_matrix(orig_train_labels, preds1)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues, show_normed=True, show_absolute=False)
#plt.xticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
#plt.yticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
plt.show()

# %% [markdown]
# ## Evaluate second Model

# %%
eval_loss2, eval_score2 = model2.evaluate(train_img, train_labels, batch_size=16)
print("Loss on test set: ", eval_loss2)
print("Accuracy on test set: ", eval_score2)
# Out:
# 5495/5495 [==============================] - 91s 17ms/step
# Loss on test set:  7.940974250460235
# Accuracy on test set:  0.26223839856040165

# %%
preds2 = model2.predict(train_img, batch_size=16)
preds2 = np.argmax(preds2, axis=-1)

# Original labels
# orig_train_labels = np.argmax(train_labels, axis=-1)

# %%
cm  = confusion_matrix(orig_train_labels, preds2)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues, show_normed=True, show_absolute=False)
#plt.xticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
#plt.yticks(range(5), ['0', '1', '2', '3', '4'], fontsize=16)
plt.show()
